# %% [markdown]
# ### import 및 함수

# %%
# dict_kcs = {"kcs" : "pullPath"}
# 20494491752A40E088201 /volume1/솔림헬프/기타/전북-01/20494491/20494491_보증인 오병석_기타_2022본11747_유체접수증.pdf
import os
import pickle
import binascii
import re
from os.path import join
from file_function import read_filelist, re_name_upload, write_log_csv_upload
from tqdm import tqdm

#################################################################
company = "솔림"
#################################################################
if company == "솔림" :
    path_kcs = r"\\192.168.0.75\스캔파일\스캔파일log\_project\파일\중복조사\kcs별 파일정보_솔림헬프.pkl"
else  : path_kcs = r"\\192.168.0.75\스캔파일\스캔파일log\_project\대성파일\중복조사\kcs별 파일정보_대성.pkl"

def crc32_checksum(filename):
    buf = open(filename,'rb').read()
    buf = (binascii.crc32(buf) & 0xFFFFFFFF)
    return "%08X" % buf

def get_kcs(path_192) :
    crc32 = str(crc32_checksum(path_192))
    size = str(os.path.getsize(path_192))
    f = os.path.split(path_192)[1]
    key = f[:8]
    kcs = key + crc32 + size 
    return kcs

def read_kcs(path_kcs) :
    with open(path_kcs, "rb") as pkl :
        return pickle.load(pkl)

def delete_kcs(filePath, dict_kcs) :
    k = os.path.split(filePath)[1][:8]
    c = str(crc32_checksum(filePath))
    s = str(os.path.getsize(filePath))
    kcs = k + c + s
    if kcs in dict_kcs :
        print(f"kcs : {kcs}   path : {dict_kcs[kcs]}")
        del dict_kcs[kcs]
    
        

def write_kcs(path_kcs, dict_kcs) :
    with open(path_kcs, "wb") as pkl :
        pickle.dump(dict_kcs, pkl)

# def update_kcs(src, dst, dict_kcs) :
    
#     kcs = get_kcs(src)
#     print(dict_kcs[kcs])

#     new_dst = re.sub(r"\\\\192.168.0.75", "/volume1", dst)
#     new_dst = re.sub(r"\\", "/", new_dst)
#     dict_kcs[kcs] = new_dst
#     print(dict_kcs[kcs], "dict수정 성공")

def update_kcs(src, dst, dict_kcs) :
    # 채무자키
    src_key = os.path.split(src)[1][:8]
    dst_key = os.path.split(dst)[1][:8]
    # kcs
    kcs = get_kcs(src)
    before_value = dict_kcs[kcs] # 수정되기 전에 변수에 담아두어야
    # 윈도우 path를 리눅스 path로
    new_dst = re.sub(r"\\\\192.168.0.75", "/volume1", dst)
    new_dst = re.sub(r"\\", "/", new_dst)

    # 채무자키가 달라졌을 때 > dict의 key를 수정해야 하므로 삭제 후 새값 추가
    if src_key != dst_key :
        new_kcs = dst_key + kcs[8:]
        del dict_kcs[kcs] # 구값 삭제
    else : new_kcs = kcs
    
    # 새값 추가/수정(채무자키 동일했다면 kcs == new_kcs 따라서 수정된다.)
    dict_kcs[new_kcs] = new_dst

    print(f"dict 키 변화 : {kcs} >>> {new_kcs}")
    print(f"dict 값 변화 : {before_value} >>> {dict_kcs[new_kcs]}")

# %% [markdown]
# ### dict load

# %%
# 읽기
dict_kcs = read_kcs(path_kcs)
print("최초dict_kcs개수 :", len(dict_kcs))
# Out:
# 최초dict_kcs개수 : 507211

# %%
dict_kcs["10622626D302827"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dict_kcs["10622626D302827"]
#
# KeyError: '10622626D302827'

# %% [markdown]
# ### 중복파일인지 확인 : 채무자키 입히기 전

# %% [markdown]
# #### 단일 파일 - 채무자키 있음

# %%
filePath = r"C:\Users\DATA\Desktop\양도\20408405_박성룡_양도통지서 현대 DNP (1).jpg"
k = os.path.split(filePath)[1][:8]
c = str(crc32_checksum(filePath))
s = str(os.path.getsize(filePath))
kcs = k + c + s
if kcs in dict_kcs :
    print(f"kcs : {kcs}   path : {dict_kcs[kcs]}")
else : 
    print("동일파일 없음")
# Out:
# kcs : 20408405784C2A1F84035   path : /volume1/솔림헬프/기타/DNP-02/20408405/20408405_박성룡_기타_양도양수계약서 (1).jpg

# %% [markdown]
# #### 폴더 전체 - 채무자키 없음

# %%
# key를 제거한 새로운 dict_cs 생성
dict_cs = {}
for key in dict_kcs:
    new_key = key[8:]  # 앞에서 8자리 문자를 지운 새로운 키 생성
    if new_key in dict_cs :
        dict_cs[new_key] = dict_cs[new_key] +","+ dict_kcs[key]
    else :
        dict_cs[new_key] = dict_kcs[key]

# %%
path = r"D:\구 스캔파일\광주 공유폴더\■초본--작업보류\국민카드 초본 - 복사본"
file_list = read_filelist(path)
total = len(file_list)
path_exist = join(path, "exist")
cnt = 0 

for f in tqdm(file_list, total=total) :
    src = join(path, f)
    crc32 = str(crc32_checksum(src))
    size = str(os.path.getsize(src))
    cs = crc32 + size
    if cs in dict_cs :
        try : 
            os.rename(src, join(path_exist, f))
            cnt += 1
        except : 
            if not os.path.exists(path_exist) : os.mkdir(path_exist)
            os.rename(src, join(path_exist, f))
            cnt += 1
print(f"총 {total}개의 파일 중 {cnt}파일 중복")
# Out:
# 100%|██████████| 4202/4202 [00:09<00:00, 428.58it/s]
# 총 4202개의 파일 중 0파일 중복

# %% [markdown]
# ### dict삭제 > 파일은 직접, 파일명 변경후 재업하면 수정작업과 동일

# %% [markdown]
# ##### 단일파일 dict 삭제

# %%
####################################
# 에브리띵에서 전체경로복사하면 편함, 채무자키만 유지하면 파일위치, 파일명는 상관없음
path_192 = r"\\192.168.0.75\솔림헬프\6.개인회생\DNP-01\20417962\20417962_보증인 최경연_개인회생_2024개회2549_개시결정.pdf"
####################################
삭제전 = len(dict_kcs)
delete_kcs(path_192, dict_kcs)
삭제후 = len(dict_kcs)
print(f'{삭제전 - 삭제후}건 중복파일 dict_kcs 정보 삭제')
# Out:
# kcs : 204179628C61386112247021   path : /volume1/솔림헬프/6.개인회생/DNP-01/20417962/20417962_보증인 최경연_개인회생_2024개회2549_개시결정.pdf
# 1건 중복파일 dict_kcs 정보 삭제

# %% [markdown]
# ##### 폴더 내 전체 파일 dict 삭제

# %%
path = r"C:\Users\DATA\Desktop\양도" # r"\\192.168.0.75\스캔파일\대성 스캔파일 업로드\구스캔파일\새 폴더"
삭제전 = len(dict_kcs)

for f in os.listdir(path) :
    path_192 = os.path.join(path, f)
    if os.path.isfile(path_192) : 
        delete_kcs(path_192, dict_kcs)
        
삭제후 = len(dict_kcs)
print(f'{삭제전 - 삭제후}건 중복파일 dict_kcs 정보 삭제')
# Out:
# kcs : 20408405784C2A1F84035   path : /volume1/솔림헬프/기타/DNP-02/20408405/20408405_박성룡_기타_양도양수계약서 (1).jpg
# kcs : 20408405FB7025FD82800   path : /volume1/솔림헬프/기타/DNP-02/20408405/20408405_박성룡_기타_양도양수계약서 (2).jpg
# kcs : 204084051FAF8ACD91384   path : /volume1/솔림헬프/기타/DNP-02/20408405/20408405_박성룡_기타_양도양수계약서.jpg
# kcs : 20411575D5B4952980708   path : /volume1/솔림헬프/기타/DNP-02/20411575/20411575_㈜서유산업_기타_양도양수계약서 (1).jpg
# kcs : 204115753334BA8779666   path : /volume1/솔림헬프/기타/DNP-02/20411575/20411575_㈜서유산업_기타_양도양수계약서 (2).jpg
# kcs : 20411575729861CC83816   path : /volume1/솔림헬프/기타/DNP-02/20411575/20411575_㈜서유산업_기타_양도양수계약서.jpg
# kcs : 2041157961F2D3E589953   path : /volume1/솔림헬프/기타/DNP-02/20411579/20411579_이미영_기타_양도양수계약서.jpg
# kcs : 20411579938B2C4079695   path : /volume1/솔림헬프/기타/DNP-02/20411579/20411579_이미영_기타_양도양수계약서_(1).jpg
# kcs : 20411580BBF33AC082343   path : /volume1/솔림헬프/기타/DNP-02/20411580/20411580_최창복_기타_양도양수계약서.jpg
# kcs : 2041158059FB570191019   path : /volume1/솔림헬프/기타/DNP-02/20411580/20411580_최창복_기타_양도양수계약서_(1).jpg
# kcs : 204115818D3B4A3C82460   path : /volume1/솔림헬프/기타/DNP-02/20411581/20411581_오춘화_기타_양도양수계약서.jpg
# kcs : 20411581633CE89679808   path : /volume1/솔림헬프/기타/DNP-02/20411581/20411581_오춘화_기타_양도양수계약서_(1).jpg
# kcs : 2041158248F1734E78719   path : /volume1/솔림헬프/기타/DNP-02/20411582/20411582_강현정_기타_양도양수계약서.jpg
# kcs : 2042212434381FE477308   path : /volume1/솔림헬프/기타/DNP-02/20422124/20422124_㈜케이유니버샬항_기타_양도양수계약서.jpg
# kcs : 2042212530C4CC4A90007   path : /volume1/솔림헬프/기타/DNP-02/20422125/20422125_㈜무비트코리_기타_양도양수계약서.jpg
# kcs : 204221264DF09B2E89214   path : /volume1/솔림헬프/기타/DNP-02/20422126/20422126_㈜위위_기타_양도양수계약서.jpg
# kcs : 20422127AA46EF2781168   path : /volume1/솔림헬프/기타/DNP-02/20422127/20422127_㈜은경산업_기타_양도양수계약서.jpg
# kcs : 2042212893F15A2680167   path : /volume1/솔림헬프/기타/DNP-02/20422128/20422128_㈜녹산코리아_기타_양도양수계약서.jpg
# kcs : 20422128EF3B8B6382852   path : /volume1/솔림헬프/기타/DNP-02/20422128/20422128_㈜녹산코리아_기타_양도양수계약서_(1).jpg
# kcs : 2042213360E33D1988920   path : /volume1/솔림헬프/기타/DNP-02/20422133/20422133_㈜아뉴타코리아_기타_양도양수계약서.jpg
# kcs : 2042213416D4302481219   path : /volume1/솔림헬프/기타/DNP-02/20422134/20422134_㈜금양통상_기타_양도양수계약서 (1).jpg
# kcs : 20422134758A153D81599   path : /volume1/솔림헬프/기타/DNP-02/20422134/20422134_㈜금양통상_기타_양도양수계약서.jpg
# kcs : 20422135C44B0F2C83169   path : /volume1/솔림헬프/기타/DNP-02/20422135/20422135_이정철_기타_양도양수계약서.jpg
# kcs : 20422136CD1AF3D882328   path : /volume1/솔림헬프/기타/DNP-02/20422136/20422136_정윤삼_기타_양도양수계약서.jpg
# kcs : 20422137FFC4113083392   path : /volume1/솔림헬프/기타/DNP-02/20422137/20422137_김형순_기타_양도양수계약서.jpg
# kcs : 20422138869628EC81387   path : /volume1/솔림헬프/기타/DNP-02/20422138/20422138_김양덕_기타_양도양수계약서.jpg
# kcs : 20422139D3C304A882778   path : /volume1/솔림헬프/기타/DNP-02/20422139/20422139_이순례_기타_양도양수계약서.jpg
# kcs : 20422141928AB38A81549   path : /volume1/솔림헬프/기타/DNP-02/20422141/20422141_주남순_기타_양도양수계약서.jpg
# kcs : 2042214217B7C49590854   path : /volume1/솔림헬프/기타/DNP-02/20422142/20422142_이동준_기타_양도양수계약서.jpg
# kcs : 20422143551DE37481548   path : /volume1/솔림헬프/기타/DNP-02/20422143/20422143_임동복_기타_양도양수계약서.jpg
# kcs : 204221433B46A05A80635   path : /volume1/솔림헬프/기타/DNP-02/20422143/20422143_임동복_기타_양도양수계약서_(1).jpg
# kcs : 2042214466B72D4B82910   path : /volume1/솔림헬프/기타/DNP-02/20422144/20422144_김주곤_기타_양도양수계약서.jpg
# kcs : 20422145D8FE13DD79609   path : /volume1/솔림헬프/기타/DNP-02/20422145/20422145_이상숙_기타_양도양수계약서 (1).jpg
# kcs : 20422145299F6F5F81755   path : /volume1/솔림헬프/기타/DNP-02/20422145/20422145_이상숙_기타_양도양수계약서.jpg
# kcs : 20422146B975948283246   path : /volume1/솔림헬프/기타/DNP-02/20422146/20422146_서분옥_기타_양도양수계약서.jpg
# kcs : 20422147B26B598681277   path : /volume1/솔림헬프/기타/DNP-02/20422147/20422147_최윤_기타_양도양수계약서.jpg
# kcs : 2042214931A9446782322   path : /volume1/솔림헬프/기타/DNP-02/20422149/20422149_허진만_기타_양도양수계약서.jpg
# kcs : 204221508D3DB4F583201   path : /volume1/솔림헬프/기타/DNP-02/20422150/20422150_임영숙_기타_양도양수계약서.jpg
# kcs : 204221519F2E872293262   path : /volume1/솔림헬프/기타/DNP-02/20422151/20422151_고낙영(고락영)_기타_양도양수계약서.jpg
# kcs : 20422152C950957090703   path : /volume1/솔림헬프/기타/DNP-02/20422152/20422152_박윤분_기타_양도양수계약서.jpg
# kcs : 20422153165C701C79611   path : /volume1/솔림헬프/기타/DNP-02/20422153/20422153_전종자_기타_양도양수계약서.jpg
# kcs : 204221557C64054190100   path : /volume1/솔림헬프/기타/DNP-02/20422155/20422155_황인성_기타_양도양수계약서.jpg
# kcs : 204221573B39436280894   path : /volume1/솔림헬프/기타/DNP-02/20422157/20422157_김정구_기타_양도양수계약서.jpg
# kcs : 2042215973E08BB381971   path : /volume1/솔림헬프/기타/DNP-02/20422159/20422159_이현옥_기타_양도양수계약서.jpg
# kcs : 20422160EE49C55680357   path : /volume1/솔림헬프/기타/DNP-02/20422160/20422160_지동욱_기타_양도양수계약서.jpg
# kcs : 20422161CD1184F182469   path : /volume1/솔림헬프/기타/DNP-02/20422161/20422161_김종식_기타_양도양수계약서.jpg
# kcs : 2042216452F9EA2D91650   path : /volume1/솔림헬프/기타/DNP-02/20422164/20422164_홍기철_기타_양도양수계약서.jpg
# kcs : 20422165A2DE3EF182325   path : /volume1/솔림헬프/기타/DNP-02/20422165/20422165_김현옥_기타_양도양수계약서.jpg
# kcs : 204221662FA6B8D379859   path : /volume1/솔림헬프/기타/DNP-02/20422166/20422166_김정중_기타_양도양수계약서.jpg
# kcs : 204221670A5F879884589   path : /volume1/솔림헬프/기타/DNP-02/20422167/20422167_서정희_기타_양도양수계약서.jpg
# kcs : 20422168C48BB5CF91426   path : /volume1/솔림헬프/기타/DNP-02/20422168/20422168_김정아_기타_양도양수계약서.jpg
# kcs : 20422169B239FFD285151   path : /volume1/솔림헬프/기타/DNP-02/20422169/20422169_권용진_기타_양도양수계약서 (1).jpg
# kcs : 204221691162D25F84869   path : /volume1/솔림헬프/기타/DNP-02/20422169/20422169_권용진_기타_양도양수계약서.jpg
# kcs : 20422170820A6B4C81546   path : /volume1/솔림헬프/기타/DNP-02/20422170/20422170_조윤빈_기타_양도양수계약서.jpg
# kcs : 2042217071B7105F91617   path : /volume1/솔림헬프/기타/DNP-02/20422170/20422170_조윤빈_기타_양도양수계약서_(1).jpg
# kcs : 204221714DD5368281357   path : /volume1/솔림헬프/기타/DNP-02/20422171/20422171_양용희_기타_양도양수계약서.jpg
# kcs : 20422172BAF26AB183389   path : /volume1/솔림헬프/기타/DNP-02/20422172/20422172_박덕주_기타_양도양수계약서.jpg
# kcs : 204221909B8FFD3882508   path : /volume1/솔림헬프/기타/DNP-02/20422190/20422190_세광알미늄산업㈜_기타_양도양수계약서.jpg
# kcs : 20422190E564C0DA80131   path : /volume1/솔림헬프/기타/DNP-02/20422190/20422190_세광알미늄산업㈜_기타_양도양수계약서_(1).jpg
# kcs : 20422191902BE63983364   path : /volume1/솔림헬프/기타/DNP-02/20422191/20422191_영일제강_기타_양도양수계약서 (1).jpg
# kcs : 2042219169839FB581951   path : /volume1/솔림헬프/기타/DNP-02/20422191/20422191_영일제강_기타_양도양수계약서.jpg
# kcs : 20422192C74D495479974   path : /volume1/솔림헬프/기타/DNP-02/20422192/20422192_김명주_기타_양도양수계약서 (1).jpg
# kcs : 20422192AF7A72A780891   path : /volume1/솔림헬프/기타/DNP-02/20422192/20422192_김명주_기타_양도양수계약서.jpg
# kcs : 20422193C7231A8983796   path : /volume1/솔림헬프/기타/DNP-02/20422193/20422193_김술임_기타_양도양수계약서.jpg
# kcs : 20422193C2C1D08982583   path : /volume1/솔림헬프/기타/DNP-02/20422193/20422193_김술임_기타_양도양수계약서_(1).jpg
# kcs : 20422194DCDFCEB590900   path : /volume1/솔림헬프/기타/DNP-02/20422194/20422194_한상원_기타_양도양수계약서.jpg
# kcs : 2042219456CF455081612   path : /volume1/솔림헬프/기타/DNP-02/20422194/20422194_한상원_기타_양도양수계약서_(1).jpg
# kcs : 204221958A1679D491872   path : /volume1/솔림헬프/기타/DNP-02/20422195/20422195_김이수_기타_양도양수계약서 (1).jpg
# kcs : 204221958707DBCD93073   path : /volume1/솔림헬프/기타/DNP-02/20422195/20422195_김이수_기타_양도양수계약서 (2).jpg
# kcs : 204221957309B29991678   path : /volume1/솔림헬프/기타/DNP-02/20422195/20422195_김이수_기타_양도양수계약서 (3).jpg
# kcs : 2042219582A1F44592100   path : /volume1/솔림헬프/기타/DNP-02/20422195/20422195_김이수_기타_양도양수계약서.jpg
# kcs : 20422196282E058279479   path : /volume1/솔림헬프/기타/DNP-02/20422196/20422196_하순남_기타_양도양수계약서 (1).jpg
# kcs : 20422196E4DE6D9689609   path : /volume1/솔림헬프/기타/DNP-02/20422196/20422196_하순남_기타_양도양수계약서 (2).jpg
# kcs : 2042219620D3CD5C89853   path : /volume1/솔림헬프/기타/DNP-02/20422196/20422196_하순남_기타_양도양수계약서 (3).jpg
# kcs : 204221964E9117CD80626   path : /volume1/솔림헬프/기타/DNP-02/20422196/20422196_하순남_기타_양도양수계약서.jpg
# kcs : 20422197B4AE5B5A84048   path : /volume1/솔림헬프/기타/DNP-02/20422197/20422197_김경숙_기타_양도양수계약서.jpg
# kcs : 2042219704A0F39A94090   path : /volume1/솔림헬프/기타/DNP-02/20422197/20422197_김경숙_기타_양도양수계약서_(1).jpg
# kcs : 204221999E61A5DD82549   path : /volume1/솔림헬프/기타/DNP-02/20422199/20422199_김선옥_기타_양도양수계약서 (1).jpg
# kcs : 20422199D29F183580913   path : /volume1/솔림헬프/기타/DNP-02/20422199/20422199_김선옥_기타_양도양수계약서 (2).jpg
# kcs : 20422199E372029480737   path : /volume1/솔림헬프/기타/DNP-02/20422199/20422199_김선옥_기타_양도양수계약서.jpg
# kcs : 20422200A0B12D9B80019   path : /volume1/솔림헬프/기타/DNP-02/20422200/20422200_김창옥_기타_양도양수계약서 (1).jpg
# kcs : 2042220030F9F0FA80518   path : /volume1/솔림헬프/기타/DNP-02/20422200/20422200_김창옥_기타_양도양수계약서 (2).jpg
# kcs : 20422200E0558A1283131   path : /volume1/솔림헬프/기타/DNP-02/20422200/20422200_김창옥_기타_양도양수계약서.jpg
# kcs : 2042220128EC18C381161   path : /volume1/솔림헬프/기타/DNP-02/20422201/20422201_박희열_기타_양도양수계약서 (1).jpg
# kcs : 204222017B48E27C82466   path : /volume1/솔림헬프/기타/DNP-02/20422201/20422201_박희열_기타_양도양수계약서.jpg
# kcs : 204222025464B3DD83177   path : /volume1/솔림헬프/기타/DNP-02/20422202/20422202_김종영_기타_양도양수계약서 (1).jpg
# kcs : 20422202C14A7E5C82310   path : /volume1/솔림헬프/기타/DNP-02/20422202/20422202_김종영_기타_양도양수계약서.jpg
# kcs : 204222030EDD873A81965   path : /volume1/솔림헬프/기타/DNP-02/20422203/20422203_이진학_기타_양도양수계약서 (1).jpg
# kcs : 20422203C1573E6078988   path : /volume1/솔림헬프/기타/DNP-02/20422203/20422203_이진학_기타_양도양수계약서.jpg
# kcs : 20422205A0ACBC0D87388   path : /volume1/솔림헬프/기타/DNP-02/20422205/20422205_장원경_기타_양도양수계약서 (1).jpg
# kcs : 204222058D0389A881700   path : /volume1/솔림헬프/기타/DNP-02/20422205/20422205_장원경_기타_양도양수계약서.jpg
# kcs : 2042220623814CAD82165   path : /volume1/솔림헬프/기타/DNP-02/20422206/20422206_김훤중_기타_양도양수계약서.jpg
# kcs : 20422206AF9A0A1479856   path : /volume1/솔림헬프/기타/DNP-02/20422206/20422206_김훤중_기타_양도양수계약서_(1).jpg
# kcs : 20422206EA2D7C9980969   path : /volume1/솔림헬프/기타/DNP-02/20422206/20422206_김훤중_기타_양도양수계약서_(2).jpg
# kcs : 20422207FD3FBD3E81733   path : /volume1/솔림헬프/기타/DNP-02/20422207/20422207_최길식_기타_양도양수계약서 (1).jpg
# kcs : 204222078A6730B880936   path : /volume1/솔림헬프/기타/DNP-02/20422207/20422207_최길식_기타_양도양수계약서.jpg
# kcs : 204222084397821D82615   path : /volume1/솔림헬프/기타/DNP-02/20422208/20422208_권옥순_기타_양도양수계약서 (1).jpg
# kcs : 2042220809BECA1882191   path : /volume1/솔림헬프/기타/DNP-02/20422208/20422208_권옥순_기타_양도양수계약서 (2).jpg
# kcs : 20422208DC0F85E781012   path : /volume1/솔림헬프/기타/DNP-02/20422208/20422208_권옥순_기타_양도양수계약서 (3).jpg
# kcs : 20422208898A3F0990158   path : /volume1/솔림헬프/기타/DNP-02/20422208/20422208_권옥순_기타_양도양수계약서.jpg
# kcs : 20422209E3E8ED4D81466   path : /volume1/솔림헬프/기타/DNP-02/20422209/20422209_김인관_기타_양도양수계약서 (1).jpg
# kcs : 20422209E922909991852   path : /volume1/솔림헬프/기타/DNP-02/20422209/20422209_김인관_기타_양도양수계약서 (2).jpg
# kcs : 20422209F0E635F183224   path : /volume1/솔림헬프/기타/DNP-02/20422209/20422209_김인관_기타_양도양수계약서 (3).jpg
# kcs : 20422209A061EF6879881   path : /volume1/솔림헬프/기타/DNP-02/20422209/20422209_김인관_기타_양도양수계약서.jpg
# kcs : 204222108507D17582275   path : /volume1/솔림헬프/기타/DNP-02/20422210/20422210_이병태_기타_양도양수계약서 (1).jpg
# kcs : 204222101255E4A481008   path : /volume1/솔림헬프/기타/DNP-02/20422210/20422210_이병태_기타_양도양수계약서.jpg
# kcs : 20422211117685BC80194   path : /volume1/솔림헬프/기타/DNP-02/20422211/20422211_권기현_기타_양도양수계약서.jpg
# kcs : 2042221140FE184093030   path : /volume1/솔림헬프/기타/DNP-02/20422211/20422211_권기현_기타_양도양수계약서_(1).jpg
# kcs : 20422212F76AFD1D89731   path : /volume1/솔림헬프/기타/DNP-02/20422212/20422212_오재익_기타_양도양수계약서 (1).jpg
# kcs : 2042221256ED58EF90319   path : /volume1/솔림헬프/기타/DNP-02/20422212/20422212_오재익_기타_양도양수계약서.jpg
# kcs : 204222137C5BEC0181780   path : /volume1/솔림헬프/기타/DNP-02/20422213/20422213_배순열_기타_양도양수계약서 (1).jpg
# kcs : 204222138568E7C984590   path : /volume1/솔림헬프/기타/DNP-02/20422213/20422213_배순열_기타_양도양수계약서.jpg
# kcs : 20422214D911AF5582071   path : /volume1/솔림헬프/기타/DNP-02/20422214/20422214_이광노_기타_양도양수계약서 (1).jpg
# kcs : 20422214AC8189F481338   path : /volume1/솔림헬프/기타/DNP-02/20422214/20422214_이광노_기타_양도양수계약서.jpg
# kcs : 20422215DA118CE977187   path : /volume1/솔림헬프/기타/DNP-02/20422215/20422215_이종준_기타_양도양수계약서.jpg
# kcs : 20422215E19EADD181401   path : /volume1/솔림헬프/기타/DNP-02/20422215/20422215_이종준_기타_양도양수계약서_(1).jpg
# kcs : 20422216735989C984120   path : /volume1/솔림헬프/기타/DNP-02/20422216/20422216_안상태_기타_양도양수계약서 (1).jpg
# kcs : 20422216B564127C80459   path : /volume1/솔림헬프/기타/DNP-02/20422216/20422216_안상태_기타_양도양수계약서 (2).jpg
# kcs : 20422216403F41A183000   path : /volume1/솔림헬프/기타/DNP-02/20422216/20422216_안상태_기타_양도양수계약서.jpg
# kcs : 20422217C0AF247184107   path : /volume1/솔림헬프/기타/DNP-02/20422217/20422217_김길용_기타_양도양수계약서.jpg
# kcs : 204222177A379D1D92876   path : /volume1/솔림헬프/기타/DNP-02/20422217/20422217_김길용_기타_양도양수계약서_(1).jpg
# kcs : 20422218338DB0C890565   path : /volume1/솔림헬프/기타/DNP-02/20422218/20422218_노세준_기타_양도양수계약서 (1).jpg
# kcs : 2042221865A66F2382371   path : /volume1/솔림헬프/기타/DNP-02/20422218/20422218_노세준_기타_양도양수계약서.jpg
# kcs : 20422219E71E62B789892   path : /volume1/솔림헬프/기타/DNP-02/20422219/20422219_박태룡 박태용_기타_양도양수계약서 (1).jpg
# kcs : 20422219994A60B481408   path : /volume1/솔림헬프/기타/DNP-02/20422219/20422219_박태룡 박태용_기타_양도양수계약서 (2).jpg
# kcs : 204222199F80153B88806   path : /volume1/솔림헬프/기타/DNP-02/20422219/20422219_박태룡 박태용_기타_양도양수계약서.jpg
# kcs : 20422220B9B8FE2883660   path : /volume1/솔림헬프/기타/DNP-02/20422220/20422220_김영기_기타_양도양수계약서 (1).jpg
# kcs : 20422220E966FFB082135   path : /volume1/솔림헬프/기타/DNP-02/20422220/20422220_김영기_기타_양도양수계약서 (2).jpg
# kcs : 2042222068D8536192342   path : /volume1/솔림헬프/기타/DNP-02/20422220/20422220_김영기_기타_양도양수계약서.jpg
# kcs : 20422221CFE81D3B81544   path : /volume1/솔림헬프/기타/DNP-02/20422221/20422221_이경진_기타_양도양수계약서.jpg
# kcs : 20422221C71EE89E82028   path : /volume1/솔림헬프/기타/DNP-02/20422221/20422221_이경진_기타_양도양수계약서_(1).jpg
# kcs : 2042222167300B8481620   path : /volume1/솔림헬프/기타/DNP-02/20422221/20422221_이경진_기타_양도양수계약서_(2).jpg
# kcs : 2042222208F8F66980498   path : /volume1/솔림헬프/기타/DNP-02/20422222/20422222_유필준_기타_양도양수계약서.jpg
# kcs : 204222220873342179540   path : /volume1/솔림헬프/기타/DNP-02/20422222/20422222_유필준_기타_양도양수계약서_(1).jpg
# kcs : 2042222311A749C383020   path : /volume1/솔림헬프/기타/DNP-02/20422223/20422223_김윤경_기타_양도양수계약서 (1).jpg
# kcs : 204222233C7FBAB391779   path : /volume1/솔림헬프/기타/DNP-02/20422223/20422223_김윤경_기타_양도양수계약서.jpg
# kcs : 204222241C0B524890135   path : /volume1/솔림헬프/기타/DNP-02/20422224/20422224_황준구_기타_양도양수계약서.jpg
# kcs : 20422224E54A0B7182071   path : /volume1/솔림헬프/기타/DNP-02/20422224/20422224_황준구_기타_양도양수계약서_(1).jpg
# kcs : 20422225E5A1BA1783464   path : /volume1/솔림헬프/기타/DNP-02/20422225/20422225_노일수_기타_양도양수계약서.jpg
# kcs : 204222251014AA4681473   path : /volume1/솔림헬프/기타/DNP-02/20422225/20422225_노일수_기타_양도양수계약서_(1).jpg
# kcs : 2042222504EC6F3889461   path : /volume1/솔림헬프/기타/DNP-02/20422225/20422225_노일수_기타_양도양수계약서_(2).jpg
# kcs : 204222267A057BBA91563   path : /volume1/솔림헬프/기타/DNP-02/20422226/20422226_정대훈_기타_양도양수계약서 (1).jpg
# kcs : 204222260C93B85A88752   path : /volume1/솔림헬프/기타/DNP-02/20422226/20422226_정대훈_기타_양도양수계약서 (2).jpg
# kcs : 204222267A89AF5183641   path : /volume1/솔림헬프/기타/DNP-02/20422226/20422226_정대훈_기타_양도양수계약서.jpg
# kcs : 20422227911F052083048   path : /volume1/솔림헬프/기타/DNP-02/20422227/20422227_이창연_기타_양도양수계약서 (1).jpg
# kcs : 20422227AF5BC55883930   path : /volume1/솔림헬프/기타/DNP-02/20422227/20422227_이창연_기타_양도양수계약서.jpg
# kcs : 20422228037A2F8478840   path : /volume1/솔림헬프/기타/DNP-02/20422228/20422228_김영라_기타_양도양수계약서 (1).jpg
# kcs : 2042222843A7A96983217   path : /volume1/솔림헬프/기타/DNP-02/20422228/20422228_김영라_기타_양도양수계약서.jpg
# kcs : 204222293CDD679180280   path : /volume1/솔림헬프/기타/DNP-02/20422229/20422229_배강순_기타_양도양수계약서 (1).jpg
# kcs : 204222291A1C01B581177   path : /volume1/솔림헬프/기타/DNP-02/20422229/20422229_배강순_기타_양도양수계약서.jpg
# kcs : 20422230D050736D81065   path : /volume1/솔림헬프/기타/DNP-02/20422230/20422230_홍성휘_기타_양도양수계약서 (1).jpg
# kcs : 20422230D67732DC79705   path : /volume1/솔림헬프/기타/DNP-02/20422230/20422230_홍성휘_기타_양도양수계약서.jpg
# kcs : 2042223175219F8E90542   path : /volume1/솔림헬프/기타/DNP-02/20422231/20422231_김금대_기타_양도양수계약서.jpg
# kcs : 204222319E1C509082051   path : /volume1/솔림헬프/기타/DNP-02/20422231/20422231_김금대_기타_양도양수계약서_(1).jpg
# kcs : 2042223145C4D08191626   path : /volume1/솔림헬프/기타/DNP-02/20422231/20422231_김금대_기타_양도양수계약서_(2).jpg
# kcs : 204222320146D98083829   path : /volume1/솔림헬프/기타/DNP-02/20422232/20422232_고세웅_기타_양도양수계약서 (1).jpg
# kcs : 2042223220708FEF82374   path : /volume1/솔림헬프/기타/DNP-02/20422232/20422232_고세웅_기타_양도양수계약서.jpg
# kcs : 204222331909A9DF81692   path : /volume1/솔림헬프/기타/DNP-02/20422233/20422233_전광현_기타_양도양수계약서 (1).jpg
# kcs : 20422233E8113F0683092   path : /volume1/솔림헬프/기타/DNP-02/20422233/20422233_전광현_기타_양도양수계약서.jpg
# kcs : 20422234789C1E1E89988   path : /volume1/솔림헬프/기타/DNP-02/20422234/20422234_윤금옥_기타_양도양수계약서 (1).jpg
# kcs : 20422234ABECC65683014   path : /volume1/솔림헬프/기타/DNP-02/20422234/20422234_윤금옥_기타_양도양수계약서 (2).jpg
# kcs : 204222345088DDCA82095   path : /volume1/솔림헬프/기타/DNP-02/20422234/20422234_윤금옥_기타_양도양수계약서.jpg
# kcs : 20422235EFF4E4E081150   path : /volume1/솔림헬프/기타/DNP-02/20422235/20422235_우영주_기타_양도양수계약서 (1).jpg
# kcs : 20422235543362D380838   path : /volume1/솔림헬프/기타/DNP-02/20422235/20422235_우영주_기타_양도양수계약서.jpg
# kcs : 204222364F98A5FE81816   path : /volume1/솔림헬프/기타/DNP-02/20422236/20422236_정시영_기타_양도양수계약서 (1).jpg
# kcs : 20422236DC61735781669   path : /volume1/솔림헬프/기타/DNP-02/20422236/20422236_정시영_기타_양도양수계약서.jpg
# kcs : 20422237411D88C982946   path : /volume1/솔림헬프/기타/DNP-02/20422237/20422237_김정민_기타_양도양수계약서 (1).jpg
# kcs : 204222372206946282713   path : /volume1/솔림헬프/기타/DNP-02/20422237/20422237_김정민_기타_양도양수계약서.jpg
# kcs : 20422238F09C901981938   path : /volume1/솔림헬프/기타/DNP-02/20422238/20422238_황성재_기타_양도양수계약서.jpg
# kcs : 20422238D3647A1379888   path : /volume1/솔림헬프/기타/DNP-02/20422238/20422238_황성재_기타_양도양수계약서_(1).jpg
# kcs : 2042223941F6A2C091789   path : /volume1/솔림헬프/기타/DNP-02/20422239/20422239_김미정_기타_양도양수계약서 (1).jpg
# kcs : 204222391FB6DAB581218   path : /volume1/솔림헬프/기타/DNP-02/20422239/20422239_김미정_기타_양도양수계약서 (2).jpg
# kcs : 204222395EA81C5281952   path : /volume1/솔림헬프/기타/DNP-02/20422239/20422239_김미정_기타_양도양수계약서.jpg
# kcs : 20422240C47603A678913   path : /volume1/솔림헬프/기타/DNP-02/20422240/20422240_이동열_기타_양도양수계약서 (1).jpg
# kcs : 2042224081BC452980214   path : /volume1/솔림헬프/기타/DNP-02/20422240/20422240_이동열_기타_양도양수계약서.jpg
# kcs : 204222414676716D83240   path : /volume1/솔림헬프/기타/DNP-02/20422241/20422241_배재은_기타_양도양수계약서.jpg
# kcs : 20422241FEEC28D682543   path : /volume1/솔림헬프/기타/DNP-02/20422241/20422241_배재은_기타_양도양수계약서_(1).jpg
# kcs : 20422242766DE9BC93293   path : /volume1/솔림헬프/기타/DNP-02/20422242/20422242_한승도_기타_양도양수계약서.jpg
# kcs : 204222426B0E558281406   path : /volume1/솔림헬프/기타/DNP-02/20422242/20422242_한승도_기타_양도양수계약서_(1).jpg
# kcs : 2042224246454F1B80559   path : /volume1/솔림헬프/기타/DNP-02/20422242/20422242_한승도_기타_양도양수계약서_(2).jpg
# kcs : 204222435FEF6D8582339   path : /volume1/솔림헬프/기타/DNP-02/20422243/20422243_임성환_기타_양도양수계약서 (1).jpg
# kcs : 20422243502C9EF782185   path : /volume1/솔림헬프/기타/DNP-02/20422243/20422243_임성환_기타_양도양수계약서.jpg
# kcs : 20422244C9377DA884332   path : /volume1/솔림헬프/기타/DNP-02/20422244/20422244_강지성_기타_양도양수계약서 (1).jpg
# kcs : 2042224470B79A5783993   path : /volume1/솔림헬프/기타/DNP-02/20422244/20422244_강지성_기타_양도양수계약서.jpg
# kcs : 204222453514619783438   path : /volume1/솔림헬프/기타/DNP-02/20422245/20422245_이흥기_기타_양도양수계약서.jpg
# kcs : 2042224694B5BA1B84918   path : /volume1/솔림헬프/기타/DNP-02/20422246/20422246_유성광_기타_양도양수계약서 (1).jpg
# kcs : 20422246EB9E748683275   path : /volume1/솔림헬프/기타/DNP-02/20422246/20422246_유성광_기타_양도양수계약서.jpg
# kcs : 20422247B7197F9188513   path : /volume1/솔림헬프/기타/DNP-02/20422247/20422247_김만호_기타_양도양수계약서 (1).jpg
# kcs : 20422247BC7593C985034   path : /volume1/솔림헬프/기타/DNP-02/20422247/20422247_김만호_기타_양도양수계약서 (2).jpg
# kcs : 20422247E4BF2AC882109   path : /volume1/솔림헬프/기타/DNP-02/20422247/20422247_김만호_기타_양도양수계약서.jpg
# kcs : 20422248C033ABCD91233   path : /volume1/솔림헬프/기타/DNP-02/20422248/20422248_김향희_기타_양도양수계약서 (1).jpg
# kcs : 20422248ACE96CC694228   path : /volume1/솔림헬프/기타/DNP-02/20422248/20422248_김향희_기타_양도양수계약서 (2).jpg
# kcs : 204222489A4F107493002   path : /volume1/솔림헬프/기타/DNP-02/20422248/20422248_김향희_기타_양도양수계약서 (3).jpg
# kcs : 20422248AE809AAE81962   path : /volume1/솔림헬프/기타/DNP-02/20422248/20422248_김향희_기타_양도양수계약서.jpg
# kcs : 20422249D046B2DD79010   path : /volume1/솔림헬프/기타/DNP-02/20422249/20422249_최금재_기타_양도양수계약서 (1).jpg
# kcs : 2042224930CD869A79575   path : /volume1/솔림헬프/기타/DNP-02/20422249/20422249_최금재_기타_양도양수계약서.jpg
# kcs : 2042225069131DF093603   path : /volume1/솔림헬프/기타/DNP-02/20422250/20422250_김정야_기타_양도양수계약서.jpg
# kcs : 20422250F7FABBFC90123   path : /volume1/솔림헬프/기타/DNP-02/20422250/20422250_김정야_기타_양도양수계약서_(1).jpg
# kcs : 20422250F6EEBB5791977   path : /volume1/솔림헬프/기타/DNP-02/20422250/20422250_김정야_기타_양도양수계약서_(2).jpg
# kcs : 20422251B7B0EE7385471   path : /volume1/솔림헬프/기타/DNP-02/20422251/20422251_윤종대_기타_양도양수계약서 (1).jpg
# kcs : 204222517196283381316   path : /volume1/솔림헬프/기타/DNP-02/20422251/20422251_윤종대_기타_양도양수계약서.jpg
# kcs : 2042225245764C8B77929   path : /volume1/솔림헬프/기타/DNP-02/20422252/20422252_손정윤(변경전손옥자)_기타_양도양수계약서.jpg
# kcs : 20422252ED51F3FC90421   path : /volume1/솔림헬프/기타/DNP-02/20422252/20422252_손정윤(변경전손옥자)_기타_양도양수계약서_(1).jpg
# kcs : 20422253316158D890374   path : /volume1/솔림헬프/기타/DNP-02/20422253/20422253_이상섭_기타_양도양수계약서.jpg
# kcs : 20422253E3D2489483292   path : /volume1/솔림헬프/기타/DNP-02/20422253/20422253_이상섭_기타_양도양수계약서_(1).jpg
# kcs : 204222540244B1D883750   path : /volume1/솔림헬프/기타/DNP-02/20422254/20422254_김재곤_기타_양도양수계약서 (1).jpg
# kcs : 20422254060A7E9F82099   path : /volume1/솔림헬프/기타/DNP-02/20422254/20422254_김재곤_기타_양도양수계약서.jpg
# kcs : 20422255D05A428E83037   path : /volume1/솔림헬프/기타/DNP-02/20422255/20422255_원창환_기타_양도양수계약서.jpg
# kcs : 204222556F5FB2F280070   path : /volume1/솔림헬프/기타/DNP-02/20422255/20422255_원창환_기타_양도양수계약서_(1).jpg
# kcs : 204222567A7BBB5793558   path : /volume1/솔림헬프/기타/DNP-02/20422256/20422256_이윤_기타_양도양수계약서 (1).jpg
# kcs : 2042225602F285E193881   path : /volume1/솔림헬프/기타/DNP-02/20422256/20422256_이윤_기타_양도양수계약서 (2).jpg
# kcs : 20422256822F797D93279   path : /volume1/솔림헬프/기타/DNP-02/20422256/20422256_이윤_기타_양도양수계약서.jpg
# kcs : 204222577C8E5C7B89129   path : /volume1/솔림헬프/기타/DNP-02/20422257/20422257_박병철_기타_양도양수계약서 (1).jpg
# kcs : 20422257C2A733A981530   path : /volume1/솔림헬프/기타/DNP-02/20422257/20422257_박병철_기타_양도양수계약서.jpg
# kcs : 204222588698A61794186   path : /volume1/솔림헬프/기타/DNP-02/20422258/20422258_이영구_기타_양도양수계약서 (1).jpg
# kcs : 2042225803C7ACA682143   path : /volume1/솔림헬프/기타/DNP-02/20422258/20422258_이영구_기타_양도양수계약서 (2).jpg
# kcs : 20422258A0DB1D7486364   path : /volume1/솔림헬프/기타/DNP-02/20422258/20422258_이영구_기타_양도양수계약서.jpg
# kcs : 2042226086B0736391170   path : /volume1/솔림헬프/기타/DNP-02/20422260/20422260_민병수_기타_양도양수계약서 (1).jpg
# kcs : 20422260B09696FE89057   path : /volume1/솔림헬프/기타/DNP-02/20422260/20422260_민병수_기타_양도양수계약서 (2).jpg
# kcs : 2042226001AF67BB91686   path : /volume1/솔림헬프/기타/DNP-02/20422260/20422260_민병수_기타_양도양수계약서.jpg
# kcs : 2042226117F7874D91859   path : /volume1/솔림헬프/기타/DNP-02/20422261/20422261_남호현_기타_양도양수계약서 (1).jpg
# kcs : 204222611554C4C591348   path : /volume1/솔림헬프/기타/DNP-02/20422261/20422261_남호현_기타_양도양수계약서 (2).jpg
# kcs : 20422261FC59013E92438   path : /volume1/솔림헬프/기타/DNP-02/20422261/20422261_남호현_기타_양도양수계약서.jpg
# kcs : 204222622A8AE5DC81097   path : /volume1/솔림헬프/기타/DNP-02/20422262/20422262_김민균_기타_양도양수계약서.jpg
# kcs : 20422262C565D5D379837   path : /volume1/솔림헬프/기타/DNP-02/20422262/20422262_김민균_기타_양도양수계약서_(1).jpg
# kcs : 20422263653377F982266   path : /volume1/솔림헬프/기타/DNP-02/20422263/20422263_윤정식_기타_양도양수계약서 (1).jpg
# kcs : 204222633F51654C83430   path : /volume1/솔림헬프/기타/DNP-02/20422263/20422263_윤정식_기타_양도양수계약서.jpg
# kcs : 20422264DBAFC06693076   path : /volume1/솔림헬프/기타/DNP-02/20422264/20422264_정용수_기타_양도양수계약서 (1).jpg
# kcs : 20422264EB5583B991176   path : /volume1/솔림헬프/기타/DNP-02/20422264/20422264_정용수_기타_양도양수계약서.jpg
# kcs : 20422265E57C890992225   path : /volume1/솔림헬프/기타/DNP-02/20422265/20422265_김성천_기타_양도양수계약서 (1).jpg
# kcs : 204222655978091F92524   path : /volume1/솔림헬프/기타/DNP-02/20422265/20422265_김성천_기타_양도양수계약서.jpg
# kcs : 20422266ED2811E583814   path : /volume1/솔림헬프/기타/DNP-02/20422266/20422266_박성용_기타_양도양수계약서 (1).jpg
# kcs : 2042226686C133EC92711   path : /volume1/솔림헬프/기타/DNP-02/20422266/20422266_박성용_기타_양도양수계약서.jpg
# kcs : 2042226723F57C7F81300   path : /volume1/솔림헬프/기타/DNP-02/20422267/20422267_김종일_기타_양도양수계약서 (1).jpg
# kcs : 20422267080F11D580454   path : /volume1/솔림헬프/기타/DNP-02/20422267/20422267_김종일_기타_양도양수계약서.jpg
# kcs : 20422268D70F13C781588   path : /volume1/솔림헬프/기타/DNP-02/20422268/20422268_박정중_기타_양도양수계약서.jpg
# kcs : 2042226888F2CCF684660   path : /volume1/솔림헬프/기타/DNP-02/20422268/20422268_박정중_기타_양도양수계약서_(1).jpg
# kcs : 2042226949FF764C89577   path : /volume1/솔림헬프/기타/DNP-02/20422269/20422269_안인숙_기타_양도양수계약서 (1).jpg
# kcs : 20422269469F488581030   path : /volume1/솔림헬프/기타/DNP-02/20422269/20422269_안인숙_기타_양도양수계약서 (2).jpg
# kcs : 20422269AA435A0A80207   path : /volume1/솔림헬프/기타/DNP-02/20422269/20422269_안인숙_기타_양도양수계약서.jpg
# kcs : 2042227032EF31D182285   path : /volume1/솔림헬프/기타/DNP-02/20422270/20422270_이성구_기타_양도양수계약서.jpg
# kcs : 20422270D081769981890   path : /volume1/솔림헬프/기타/DNP-02/20422270/20422270_이성구_기타_양도양수계약서_(1).jpg
# kcs : 20422270432DFF3289944   path : /volume1/솔림헬프/기타/DNP-02/20422270/20422270_이성구_기타_양도양수계약서_(2).jpg
# kcs : 20422271D5825C5A80879   path : /volume1/솔림헬프/기타/DNP-02/20422271/20422271_최준호_기타_양도양수계약서.jpg
# kcs : 2042227138BED93988191   path : /volume1/솔림헬프/기타/DNP-02/20422271/20422271_최준호_기타_양도양수계약서_(1).jpg
# kcs : 20422272492709EC89427   path : /volume1/솔림헬프/기타/DNP-02/20422272/20422272_이영철_기타_양도양수계약서 (1).jpg
# kcs : 20422272DE0B28FE91796   path : /volume1/솔림헬프/기타/DNP-02/20422272/20422272_이영철_기타_양도양수계약서 (2).jpg
# kcs : 20422272D3D679D479710   path : /volume1/솔림헬프/기타/DNP-02/20422272/20422272_이영철_기타_양도양수계약서.jpg
# kcs : 20422273E21F1A5181054   path : /volume1/솔림헬프/기타/DNP-02/20422273/20422273_오창우_기타_양도양수계약서 (1).jpg
# kcs : 20422273B2FF359791446   path : /volume1/솔림헬프/기타/DNP-02/20422273/20422273_오창우_기타_양도양수계약서.jpg
# kcs : 204222746296B62886238   path : /volume1/솔림헬프/기타/DNP-02/20422274/20422274_전성종_기타_양도양수계약서 (1).jpg
# kcs : 204222747D2F8A9483023   path : /volume1/솔림헬프/기타/DNP-02/20422274/20422274_전성종_기타_양도양수계약서 (2).jpg
# kcs : 20422274886D507281831   path : /volume1/솔림헬프/기타/DNP-02/20422274/20422274_전성종_기타_양도양수계약서.jpg
# kcs : 204222755EEE6F9080191   path : /volume1/솔림헬프/기타/DNP-02/20422275/20422275_권창근_기타_양도양수계약서.jpg
# kcs : 204222756AE2709382409   path : /volume1/솔림헬프/기타/DNP-02/20422275/20422275_권창근_기타_양도양수계약서_(1).jpg
# kcs : 2042227504FB23A783061   path : /volume1/솔림헬프/기타/DNP-02/20422275/20422275_권창근_기타_양도양수계약서_(2).jpg
# kcs : 20422276226C15A480805   path : /volume1/솔림헬프/기타/DNP-02/20422276/20422276_김용빈_기타_양도양수계약서.jpg
# kcs : 20422288E43C471579209   path : /volume1/솔림헬프/기타/DNP-02/20422288/20422288_신재욱_기타_양도양수계약서.jpg
# kcs : 20429996CEC1410B83423   path : /volume1/솔림헬프/기타/케이에스/20429996/20429996_이용자_기타_양도양수계약서.jpg
# kcs : 20429996B0A5387B79895   path : /volume1/솔림헬프/기타/케이에스/20429996/20429996_이용자_기타_양도양수계약서_(1).jpg
# kcs : 2045858761E5AAAA90230   path : /volume1/솔림헬프/기타/DNP-02/20458587/20458587_주 나라커뮤니케이_기타_양도양수계약서.jpg
# kcs : 20458590F6D8391590537   path : /volume1/솔림헬프/기타/DNP-02/20458590/20458590_임종대_기타_양도양수계약서 (1).jpg
# kcs : 20458590360ACF8F91211   path : /volume1/솔림헬프/기타/DNP-02/20458590/20458590_임종대_기타_양도양수계약서.jpg
# kcs : 20458591202AD25782740   path : /volume1/솔림헬프/기타/DNP-02/20458591/20458591_박남숙_기타_양도양수계약서.jpg
# kcs : 20458593CF50A1C183967   path : /volume1/솔림헬프/기타/DNP-02/20458593/20458593_김연석_기타_양도양수계약서.jpg
# kcs : 204586002CC3A57C80296   path : /volume1/솔림헬프/기타/DNP-02/20458600/20458600_김동찬_기타_양도양수계약서.jpg
# kcs : 20458602819C50F481619   path : /volume1/솔림헬프/기타/DNP-02/20458602/20458602_조태화_기타_양도양수계약서.jpg
# kcs : 204586104D29F10184362   path : /volume1/솔림헬프/기타/DNP-02/20458610/20458610_권창석_기타_양도양수계약서 (1).jpg
# kcs : 204586101A19730F79409   path : /volume1/솔림헬프/기타/DNP-02/20458610/20458610_권창석_기타_양도양수계약서.jpg
# kcs : 20458611A8B21EB283363   path : /volume1/솔림헬프/기타/DNP-02/20458611/20458611_박효덕_기타_양도양수계약서 (1).jpg
# kcs : 20458611CD7577F179849   path : /volume1/솔림헬프/기타/DNP-02/20458611/20458611_박효덕_기타_양도양수계약서 (2).jpg
# kcs : 204586111A8BC77F93835   path : /volume1/솔림헬프/기타/DNP-02/20458611/20458611_박효덕_기타_양도양수계약서.jpg
# kcs : 204586123F0B923588782   path : /volume1/솔림헬프/기타/DNP-02/20458612/20458612_김영학_기타_양도양수계약서 (1).jpg
# kcs : 20458612C80DE7E779572   path : /volume1/솔림헬프/기타/DNP-02/20458612/20458612_김영학_기타_양도양수계약서.jpg
# kcs : 20458613D95E2B1C80652   path : /volume1/솔림헬프/기타/DNP-02/20458613/20458613_천재윤 변경전천윤석_기타_양도양수계약서.jpg
# -275건 중복파일 dict_kcs 정보 삭제

# %% [markdown]
# ##### dict 파일로 저장

# %%
print(len(dict_kcs))
write_kcs(path_kcs, dict_kcs)
# Out:
# 507210

# %% [markdown]
# ##### 파일 삭제/이동

# %%
# 관리제외 폴더로 이동
import shutil
src = path_192
dst_d = join(r"\\192.168.0.75\삭제예정파일\관리제외", src.split(os.path.sep)[-3], src.split(os.path.sep)[-2])
if not os.path.exists(dst_d) : os.makedirs(dst_d)
dst = join(dst_d, src.split(os.path.sep)[-1])
shutil.move(src, dst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10048\3421303146.py in <cell line: 3>()
#       1 # 관리제외 폴더로 이동
#       2 import shutil
# ----> 3 src = path_192
#       4 dst_d = join(r"\\192.168.0.75\삭제예정파일\관리제외", src.split(os.path.sep)[-3], src.split(os.path.sep)[-2])
#       5 if not os.path.exists(dst_d) : os.makedirs(dst_d)
#
# NameError: name 'path_192' is not defined

# %% [markdown]
# ### dict 수정
# - 폴더 달라질 때는 그냥 새로 업로드하는게 낫겠다.

# %%
########################################################### 20514967
src = r"\\192.168.0.75\솔림헬프\3.집행권원\DNP-01\20414371\20414371_조영민_집행권원.pdf"
dst = r"\\192.168.0.75\솔림헬프\3.집행권원\DNP-01\20414371\20414371 조영민 2023차전102996.pdf"
###########################################################

# 1) dict 수정
update_kcs(src, dst, dict_kcs)
# Out:
# dict 키 변화 : 20414371ECD2146F176769 >>> 20414371ECD2146F176769
# dict 값 변화 : /volume1/솔림헬프/3.집행권원/DNP-01/20414371/20414371_조영민_집행권원.pdf >>> /volume1/솔림헬프/3.집행권원/DNP-01/20414371/20414371 조영민 2023차전102996.pdf

# %%
# 2) 파일수정 : dict보다 먼저 하면 kcs를 읽을 수가 없음
os.rename(src, dst)
print("파일명(경로) 수정 성공")
# Out:
# 파일명(경로) 수정 성공

# %%
# 3) dict 파일로 저장 # 약 20초 소요
write_kcs(path_kcs, dict_kcs)

# %% [markdown]
# #### 폴더 내 여러 파일

# %%
########################################################
path = r"\\192.168.0.75\솔림헬프\5.등초본\한울가람\20419713"
for f in os.listdir(path) :
    src = join(path, f)
    dst_file = re.sub("염직", "88염직", f)
    ####################################
    dst = join(path, dst_file)
    if src != dst :
        update_kcs(src, dst, dict_kcs)
        os.rename(src, dst)
# Out:
# dict 키 변화 : 20419713364E4B38368410 >>> 20419713364E4B38368410
# dict 값 변화 : /volume1/솔림헬프/5.등초본/한울가람/20419713/20419713_염직 보증인 강태수_초본_220926.pdf >>> /volume1/솔림헬프/5.등초본/한울가람/20419713/20419713_88염직 보증인 강태수_초본_220926.pdf

# %%
write_kcs(path_kcs, dict_kcs)
