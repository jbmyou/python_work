# %%
import pandas as pd
import pickle
import re
import os
from os.path import join

# %%
base_path = r"D:\0.전산\2.이관\0.자산정리"
debt = pd.read_pickle(join(base_path, "채무자조회새창_20230103_1658.pkl"))
account = pd.read_pickle(join(base_path, "계좌조회새창_20230103_1701.pkl"))
print(len(debt), len(account))
print("debt-----------------")
print(list(debt.columns))
print("account-----------------")
print(account.columns)
# Out:
# 70793 78155
# debt-----------------
# Index(['채무자키', '매각사구분', '채권구분', '수', '성명', '주민번호인', '담당자', '채무상태자동', '채무상태',
#        '현재채권구분',
#        ...
#        '관리자사건결과', '기타우편번호', '기타주소', '기타번지인', '기타주소메모', '우편발송금지', '매입일', '문자예약',
#        '법조치관할법원', '법조치사건번호'],
#       dtype='object', length=156)
# account-----------------
# Index(['채무자키', '채권구분', '매각사구분', '계좌키', '계좌번호', '시효완성일', '시효완성월', '매입일',
#        '최초대출일', '대출만기일', '최초연체일', '계정과목', '은행대출원금', '최초원금', '최초법비용', '최초미수이자',
#        '최초연체이자', '최초합계', '회수원금', '회수법비용', '회수미수이자', '회수정상이자', '회수연체이자', '회수기타',
#        '회수합계', '현재원금', '현재법비용', '현재미수이자', '현재정상이자', '현재연체이자', '현재합계', '이자율',
#        '연체이자율', '매입최초원금', '매입최초법비용', '매입최초미수이자', '종결일', '잔여회차', '분납형태', '원채권사',
#        '매각사', '현재채권구분', '컷오프일', '원인서류확인여부', '문서번호', '최초시효완성일메모', '최초시효완성일',
#        '최초이자기준일', '가상계좌은행', '가상계좌번호', 'OPB', '시효완성여부', '시효연장사유', '시효중단여부',
#        '메모', '비고', '기타', '사원성명', '결제결과', '최초연체개월', '연체개월', '결제일', '연체이자시작일',
# ...

# %%
print(list(debt.columns))
# Out:
# ['채무자키', '매각사구분', '채권구분', '수', '성명', '주민번호인', '담당자', '채무상태자동', '채무상태', '현재채권구분', '결제일', '결제결과', '연체개월', '성별', '연령', '원채권사', '매각사', '공탁금', '회생관할법원', '회생사건번호', '회생사건결과전', '회생사건결과', '최초원금', '최초법비용', '최초미수이자', '최초합계', '회수원금', '회수법비용', '회수미수이자', '회수정상이자', '회수연체이자', '회수합계', '현재원금', '현재법비용', '현재미수이자', '현재정상이자', '현재연체이자', '현재합계', 'OPB', '회수기타', '가수금환급액', '가수금환급일', '가수금상태', '가수금상태일', '추심착수전송결과', '담당자메모', '관리자메모', '담당자비고', '관리자비고', '담당자기타', '관리자기타', '비고', '특이사항', '기타', '회생메모', '자택전화인', '직장전화인', '핸드폰인', '자택우편번호', '자택주소', '자택번지인', '직장우편번호', '직장주소', '직장번지인', '직장명인', '초본우편번호', '초본주소', '초본번지인', '우편발송일', '우편발송결과', '반송사유', '반송일', '초본발급일', '전입일', '완제여부', '개인정보처리여부', '개인법인', '세대주관계', '강조여부', '가상계좌은행', '가상계좌번호', '담당자키', '담당연락처', '담당핸드폰', '담당변경일', '전담당자', '지점', '부서', '팀', '지역지점', '지역코드', '민원접수', '총분납금', '분납잔금', '분납연체일', '잔여회차', '분납형태', '채무자등급', '종결일', '보증인성명', '보증인상태', '최종메모등록일', '최종거래일', '타채무자키', '시효완성일', '문서번호', '차량번호', '원인서류확인여부', '변경전성명인', '변경전주민번호인', '등록파일', '수정파일', '삭제여부', '원채권키', '입금수', '계좌수', '보증
# ...

# %%
debt_org = pd.DataFrame(None, columns=["일련번호", "주민등록", "개인/법인", "금융기관 담보제공 여부", "상태", "OPB", "원채권자", "최초대출원금", "최초가지급금"])
account_org = pd.DataFrame(None)

# %%
debt_org = debt.loc[:,["채무자키", "주민번호인", "개인법인", ]]
