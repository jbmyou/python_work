# %% [markdown]
# ### import

# %%
import pandas as pd
import numpy as np
import pickle
import os
from os.path import join
import re
from file_function import re_name_upload, write_log_csv_upload
from tqdm import tqdm
from datetime import datetime, timedelta

# %%
df = pd.read_excel(r"D:\0.전산\2.이관\써머리\전북\채무자조회새창_20230116_1322_전북.xlsx")
# Out:
# c:\Users\sl\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_grt = pd.read_excel(r"D:\0.전산\2.이관\써머리\전북\보증인새창_20230116_1323_전북.xlsx")
# Out:
# c:\Users\sl\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.채무상태.value_counts()
# Out:
# 정상           2262
# 종결             68
# 환매             64
# 신용회복(확정)       17
# 개인회생(진행중)      14
# 개인회생(확정)        7
# 신용회복(진행중)       5
# 파산(확정)          4
# 파산(진행중)         4
# 파산(면책)          2
# Name: 채무상태, dtype: int64

# %%
df_norm_debt = df[~df.채무상태.str.contains("종결|환매") & ~df.담당자.str.contains("환매|매각|파산")] 
df_norm_debt.to_excel(r"D:\0.전산\2.이관\써머리\전북\정상채무_채무자_1.xlsx", index=False)

# %%
df_check_debt = df[df.채무상태.str.contains("파산|이민|사망")].loc[:,["채무자키","성명","주민번호인","채무상태","담당자"]]

# %%
df_check_debt.to_excel(r"D:\0.전산\2.이관\써머리\전북\파산자리스트.xlsx", index=False)

# %%
df_norm_debt[(df_norm_debt.개인법인=="개인") & ~(df_norm_debt.성별.str.contains(r"남자|여자", regex=True))]
# Out:
# Empty DataFrame
# Columns: [채무자키, 매각사구분, 채권구분, 수, 성명, 주민번호인, 담당자, 채무상태자동, 채무상태, 현재채권구분, 결제일, 결제결과, 연체개월, 성별, 연령, 원채권사, 매각사, 공탁금, 회생관할법원, 회생사건번호, 회생사건결과전, 회생사건결과, 최초원금, 최초법비용, 최초미수이자, 최초합계, 회수원금, 회수법비용, 회수미수이자, 회수정상이자, 회수연체이자, 회수합계, 현재원금, 현재법비용, 현재미수이자, 현재정상이자, 현재연체이자, 현재합계, OPB, 회수기타, 가수금환급액, 가수금환급일, 가수금상태, 가수금상태일, 추심착수전송결과, 담당자메모, 관리자메모, 담당자비고, 관리자비고, 담당자기타, 관리자기타, 비고, 특이사항, 기타, 회생메모, 자택전화인, 직장전화인, 핸드폰인, 자택우편번호, 자택주소, 자택번지인, 직장우편번호, 직장주소, 직장번지인, 직장명인, 초본우편번호, 초본주소, 초본번지인, 우편발송일, 우편발송결과, 반송사유, 반송일, 초본발급일, 전입일, 완제여부, 개인정보처리여부, 개인법인, 세대주관계, 강조여부, 가상계좌은행, 가상계좌번호, 담당자키, 담당연락처, 담당핸드폰, 담당변경일, 전담당자, 지점, 부서, 팀, 지역지점, 지역코드, 민원접수, 총분납금, 분납잔금, 분납연체일, 잔여회차, 분납형태, 채무자등급, 종결일, 보증인성명, ...]
# Index: []
#
# [0 rows x 156 columns]

# %%
# Out:
#              0           1      2    3               4                    5   \
# 731  20495425.0  20496010.0  전북-01   문용  611212-1009511  0001-0710-1234-7781
# 732  20495526.0  20494701.0  전북-01  김민희  650111-2482510  4599-0390-0020-5796
# 733  20495540.0  20494702.0  전북-01  김민희  650111-2482510  4599-0390-0020-5804
# 734  20495725.0  20494703.0  전북-01  김민희  650111-2482510  4599-0390-0020-5812
# 967  20496776.0         NaN    NaN  NaN             NaN                  NaN
# ..          ...         ...    ...  ...             ...                  ...
# 822         NaN  20495134.0  전북-01  김익수  521210-1496512  4599-0390-0038-8840
# 823         NaN  20494487.0  전북-01  박영오  550922-1542616  0000-6017-1039-9288
# 824         NaN  20495750.0  전북-01  고명란  660215-2405919  0001-0710-1149-6278
# 825         NaN  20494390.0  전북-01  김윤식  570308-1543511  0000-7117-3000-1595
# 826         NaN  20494391.0  전북-01  김윤식  570308-1543511  0000-7117-6000-4465
#
#        6           7    8    9   ...          30          31    32   33   34  \
# 731   NaN  주식회사 티비온티비  NaN   정상  ...  2017-09-14         NaN   NaN  NaN  NaN
# 732   NaN   유한회사 대승산업  NaN   정상  ...  2012-02-21         NaN   NaN  NaN  NaN
# 733   NaN   유한회사 대승산업  NaN   정상  ...  2012-02-21         NaN   NaN  NaN  NaN
# 734   NaN   유한회사 대승산업  NaN   정상  ...  2012-02-21         NaN   NaN  NaN  NaN
# 967   NaN         NaN  NaN  NaN  ...         NaN         NaN   NaN  NaN  NaN
# ..    ...         ...  ...  ...  ...         ...         ...   ...  ...  ...
# 822  대표이사   (유)대한정보통신  NaN   종결  ...  2004-09-14  2022-10-31  채무종결  NaN  NaN
# 823   NaN     (유)금강상사  NaN   정상  ...         NaN         NaN   NaN  NaN  NaN
# 824   NaN       동양전자㈜  NaN   정상  ...         NaN         NaN   NaN  NaN  NaN
# 825   NaN         백남연  NaN   정상  ...         NaN         NaN   NaN  NaN  NaN
# 826   NaN         백남연  NaN   정상  ...         NaN         NaN   NaN  NaN  NaN
#
#               35           36     37     38   39
# 731  200197364.0  201019149.0  ㈜전북은행  ㈜전북은행  김대홍
# 732  200197365.0  201017840.0  ㈜전북은행  ㈜전북은행  양승구
# 733  200197366.0  201017841.0  ㈜전북은행  ㈜전북은행  양승구
# 734  200197367.0  201017842.0  ㈜전북은행  ㈜전북은행  양승구
# 967          NaN          NaN    NaN    NaN  NaN
# ..           ...          ...    ...    ...  ...
# 822  200198752.0  201018273.0  ㈜전북은행  ㈜전북은행   종결
# 823  200198753.0  201017626.0  ㈜전북은행  ㈜전북은행  양승구
# 824  200198754.0  201018889.0  ㈜전북은행  ㈜전북은행  양승구
# 825  200199523.0  201017529.0  ㈜전북은행  ㈜전북은행  전병만
# 826  200199524.0  201017530.0  ㈜전북은행  ㈜전북은행  전병만
#
# [833 rows x 40 columns]

# %% [markdown]
# ### 함수 및 전역변수

# %%
path_base = r"D:\0.전산\전산조회"
p_totalyOut = re.compile(r"환매|매각|종결")
p_debt = re.compile(r"파산")
p_grt = re.compile(r"파산\(면책\)|환매|매각|종결|보증면탈")
# p_debt = re.compile(r"개인회생\(면책\)|파산\(면책\)")
# p_grt = re.compile(r"개인회생\(면책\)|파산\(면책\)|환매|매각|종결|보증면탈")

def preprocess(file:str) :
    """
    '키'칼럼의 dtype 변환(모든 값이 문자열이 된다.) : int|float > str(object), object는 유지(어차피 date형식이라도 읽어보면 str이다.)
    Nan > 빈문자열
    : 제거
    사건번호에서 공백 제거
    """
    df = pd.read_excel(join(path_base, file))
    print("타입변경 전-------------------")
    print(df.dtypes.value_counts())
    
    for c, v in tqdm(df.items(), total=len(df.columns)) :
        # 키칼럼의 타입바꾸기 float > int > str
        if "키" in c :
            if v.dtype == float : 
                df[c] = df[c].fillna(0).astype(int) # nan있으면 에러나므로 0으로 
                df[c] = df[c].replace(0, "") # 0을 ""로 바꿈
                df[c] = df[c].astype(str) # 문자열로
                # int > str
            elif (v.dtype == int) or (v.dtype == "int64") : # float == float64, int == int32
                df[c] = df[c].replace(0, "")
                df[c] = df[c].astype(str)
            else :
                df[c] = df[c].fillna("")

        # : 는 공백으로 대체
        df[c] = df[c].str.replace(":", " ")

        # 사건번호에서 공백 제거
        if re.search("사건번호", c) :
            df[c] = df[c].str.replace(" ", "")

    print("타입변경 후-------------------")
    print(df.dtypes.value_counts())
    print(df.columns)

    return df

def unite_debt_state (df_debt, df_grt) :
    """df타입의 채무자조회창과, 보증인조회창으로 채무상태만 통합. \n
    return df_united \n
    이후 is_out함수 호출"""
    채무자키 = df_debt["채무자키"]
    채무자상태 = df_debt["채무상태"]
    보증인수 = []
    보증인상태 = []
    for key in tqdm(채무자키, total=len(채무자키), desc="채무상태 통합 중") :
        temp = df_grt[df_grt.채무자키==key]
        보증인수.append(len(temp))
        보증인상태.append(temp.보증인상태.to_list())
    df_united = pd.DataFrame({"채무자키":채무자키, "채무자상태":채무자상태, "보증인수":보증인수, "보증인상태":보증인상태})
    return df_united

def is_out_df(df_united, date_of_data:str) :
    """채무자상태와 보증인상태를 통합한 df를 주면 out칼럼을 추가 \n
    통합상태.xlsx와 outList.pkl을 만듦
    """
    out_list = []
    for i, v in tqdm(df_united.iterrows(), total=len(df_united.index), desc="out여부확인중") :
        if p_totalyOut.match(v.채무자상태) : 
            out_list.append(True)
        elif p_debt.match(v.채무자상태) :  # 채무자는 일단 T(out)
            if v.보증인수 == 0 :
                out_list.append(True)
            else : # 보증인도 모두 out인 경우만 True, 보증인 한명이라도 살아있으면 False -> map과 all()활용
                out_list.append(all(map(lambda x : bool(p_grt.search(x)), v.보증인상태)))
        else : out_list.append(False)
    
    df_united["통합상태"] = out_list

    # 채무자키, 채무자-보증인상태, 통합상태 엑셀저장
    df_united.to_excel(join(path_base, "통합상태_"+date_of_data+".xlsx"), index=False)
    # out(True)인경우만 pkl저장( 타입은 sr >> "채무자키" in sr.values )
    outList = df_united[df_united["통합상태"]]["채무자키"].astype(str) # 통합상태는 T/F이므로 바로 불리언 색인가능
    outList.to_pickle(join(path_base, "outList_"+date_of_data+".pkl"))


# 채무자키가 주어짐
# def is_out (key:str, df_debt, df_grt) :
#     """채무자조회, 보증인조회에서 단일"키"를 주면 out인지(T) 아닌지(F) 판별해주는 함수"""
#     ### 검색결과가 항상 하나인 시리즈의 경우 values[0] 통해 값을 받을 수 잇다.
#     cond_grt = True
#     # 보증인 무관하게 out 
#     if df_debt[df_debt.채무자키 == key].채무상태.str.match(p_totalyOut).values[0] : #True/False
#         return True
    
#     # 채무자는 out 사용
#     elif df_debt[df_debt.채무자키 == key].채무상태.str.match(p_debt).values[0] :
#         # 보증인들(한명이라도 out이 아니면 False)
#         temp_sr = df_grt[df_grt.채무자키 == key].보증인상태
#         if len(temp_sr) == 0 : # 보증인 없음 따라서 채무자상태에 의해 out
#             return True
#         else :
#             for i in temp_sr :
#                 i = i.strip()
#                 if p_grt.match(i) == None : # 상태 검사 : out상태가 아닌 경우 발생 
#                     cond_grt = False
#                     break # 한명만 out 아니어도 out x
#             return cond_grt
                    
#     else : return False  # 채무자가 out아님

def dict_referFnc(path_df):
    """dict_refer["key"][0:매각사, 1:채무상태, 2:채무자성명, 3:보증인성명]"""
    df_c = pd.read_pickle(path_df).fillna("")
    return dict(map(lambda x : (str(x[1].채무자키),[x[1].매각사구분, x[1].채무상태, x[1].성명, x[1].보증인성명]), df_c.iterrows()))

# %% [markdown]
# ### 전처리, 조회.xlsx > pkl(df타입)

# %%
########################################
#file_name_list = ["채무자조회새창_20221220_1128", "보증인새창_20221222_1650", "법조치조회새창_20221220_1246"]
path_base = r"D:\0.전산\2.이관\써머리\전북"
file_name_list = ["계좌조회새창_20230103_1701", "채무자조회새창_20230103_1658"]
########################################
for file_name in file_name_list :
    # 전처리
    df = preprocess(join(path_base, file_name+".xlsx"))
    # 정렬하기, 연속채무자키의 경우 현재원금 큰 게 아니라 가장 앞에 있는 채무자키에 파일이 올라가있다.
    df = df.sort_values(["매각사", "주민번호인", "원채권사", "채무자키"], ascending=False)
    # pkl
    df.to_pickle(join(path_base, file_name+".pkl"))
# Out:
# c:\Users\sl\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 타입변경 전-------------------
# object     35
# int64      33
# float64    27
# dtype: int64
# 100%|██████████| 95/95 [00:01<00:00, 57.41it/s]
# 타입변경 후-------------------
# object    95
# dtype: int64
# Index(['채무자키', '채권구분', '매각사구분', '계좌키', '계좌번호', '시효완성일', '시효완성월', '매입일',
#        '최초대출일', '대출만기일', '최초연체일', '계정과목', '은행대출원금', '최초원금', '최초법비용', '최초미수이자',
#        '최초연체이자', '최초합계', '회수원금', '회수법비용', '회수미수이자', '회수정상이자', '회수연체이자', '회수기타',
#        '회수합계', '현재원금', '현재법비용', '현재미수이자', '현재정상이자', '현재연체이자', '현재합계', '이자율',
#        '연체이자율', '매입최초원금', '매입최초법비용', '매입최초미수이자', '종결일', '잔여회차', '분납형태', '원채권사',
#        '매각사', '현재채권구분', '컷오프일', '원인서류확인여부', '문서번호', '최초시효완성일메모', '최초시효완성일',
#        '최초이자기준일', '가상계좌은행', '가상계좌번호', 'OPB', '시효완성여부', '시효연장사유', '시효중단여부',
#        '메모', '비고', '기타', '사원성명', '결제결과', '최초연체개월', '연체개월', '결제일', '연체이자시작일',
#        '최초이자율', '최초연체이자율', '원채권키', '상환방법', '담보', '채무자명', '채무자주민번호', '채무상태',
#        '타채무자키', '타계좌키', '담보제공처', '담보제공구분', '채권매각처', '채권매각일', '채권매각대금', '채권환매일',
#        '채권환매대금', '채권손실일', '채권손실금액', '법조치채무종류', '계약일', '최종거래일', '최초최종거래일',
#        '계좌조정일', '계좌조정취소일', '계좌조정사유', '보증인수', '만기이자율', '나이스집중여부', '마이데이터전송',
#        '마이데이터채무조정', '리파이낸싱'],
#       dtype='object')
# c:\Users\sl\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 타입변경 전-------------------
# object     85
# int64      51
# float64    20
# dtype: int64
# 100%|██████████| 156/156 [00:03<00:00, 41.55it/s]
# 타입변경 후-------------------
# object    156
# dtype: int64
# Index(['채무자키', '매각사구분', '채권구분', '수', '성명', '주민번호인', '담당자', '채무상태자동', '채무상태',
#        '현재채권구분',
#        ...
#        '관리자사건결과', '기타우편번호', '기타주소', '기타번지인', '기타주소메모', '우편발송금지', '매입일', '문자예약',
#        '법조치관할법원', '법조치사건번호'],
#       dtype='object', length=156)

# %% [markdown]
# ### dict_refer, outList만들기

# %%
# dict_refer 만들기
######################################
new_win_name = "채무자조회새창_20221220_1128.pkl"
######################################
date_of_data = new_win_name.split("_")[1]
dict_refer_filename = "dict_refer_"+date_of_data+".pkl"
dict_refer = dict_referFnc(join(path_base, new_win_name)) # 필요한 컬럼만 모아서 dict만들기
print(len(dict_refer))

# dict_refer.pkl 만들기
with open(join(path_base, dict_refer_filename), 'wb') as pkl :
    pickle.dump(dict_refer, pkl)
# load 확인
with open(join(path_base, dict_refer_filename), 'rb') as pkl :
    dict_refer1 = pickle.load(pkl)

cnt = 0
for k, v in dict_refer1.items() :
    print(k, v) 
    cnt+=1
    if cnt>3 : break
# Out:
# 70793
# 20495151 ['전북-01', '정상', '(유)가람건설', '김원목']
# 20495152 ['전북-01', '정상', '(유)가람건설', '김원목']
# 20495238 ['전북-01', '정상', '(유)가람건설', '김원목']
# 20417854 ['DNP-01', '정상', '(유)가람관광여행사', '김길배']

# %%
# outList 만들기
############################################
debt_newwin_pkl = "채무자조회새창_20221220_1128.pkl"
grt_newwin_pkl = "보증인새창_20221220_1143.pkl"
############################################
date_of_data = debt_newwin_pkl.split("_")[1]

df_debt = pd.read_pickle(join(path_base, debt_newwin_pkl))
df_grt = pd.read_pickle(join(path_base, grt_newwin_pkl)) 

df_united = unite_debt_state(df_debt, df_grt)
is_out_df(df_united, date_of_data)
# Out:
# 채무상태 통합 중: 100%|██████████| 70793/70793 [00:34<00:00, 2034.41it/s]
# out여부확인중: 100%|██████████| 70793/70793 [00:01<00:00, 38597.19it/s]

# %% [markdown]
# ##### outList 예외 반영하기

# %%
# ex) 파산면책인데 당사누락인 경우 
# 신경용 20415606, 20431042
#######################
path_outList_pkl = join(path_base, "outList_20221220.pkl")
temp = pd.read_pickle(path_outList_pkl)
len(temp)
# Out:
# 10232

# %%
keys = ["20431042"]
for key in keys :
    temp.drop(temp[temp==key].index, inplace=True)
len(temp)
# Out:
# 10231

# %%
temp.to_pickle(path_outList_pkl)
# outList.pkl 나스 폴더로 복사 ~~

# %% [markdown]
# ### 법조치 - 그냥 pkl로만 저장
# - preprocess 안 거쳤으면 채무자키 str으로 변환 : df_event.채무자키.apply(str)

# %%
path_base = r"D:\3.자산\전산 dataset\230309_사건번호0제거"
filename = "법조치조회새창_20230309_1549_0제거후"

# %%
# # 최초 pkl 만들기
# df_event = pd.read_excel(join(path_base, filename + ".xlsx"))
# df_event.to_pickle(join(path_base, filename + ".pkl"))
# Out:
# c:\Users\sl\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_event = pd.read_pickle(join(path_base, filename+".pkl"))
df_event = df_event[["채무자키", "대상자명", "매각사구분", "매각사", "법조치키","관할법원", "사건번호", "관련사건번호", "관련법조치사건번호"]]

# %%
df_event.채무자키 = df_event.채무자키.apply(str)
df_event.to_pickle(join(r"D:\1.전산,개발\3.파일서버관리\0.월별전산조회", filename+"스캔파일작업용.pkl"))

# %% [markdown]
# ### 살릴거, 죽일거

# %% [markdown]
# ##### 살릴 거(revive = 구out - 신out)

# %%
# 신구 outList 읽기
##################################
outList_name_old = "outList_221118.pkl"
outList_name_new = "outList_20221220.pkl"
##################################
stem = os.path.splitext(outList_name_new)[0]
date_of_data = stem.split("_")[1]

set_outList_old = set(pd.read_pickle(join(path_base,"2.dict_refer, ouList구버전", outList_name_old)))
set_outList_new = set(pd.read_pickle(join(path_base, outList_name_new)))

# 살릴거(revive) 구하기
set_revive = set_outList_old - set_outList_new

# 살릴 거 있으면 저장해두고 작업하자
if len(set_revive) > 0 :
    sr_revive = pd.Series(list(set_revive), name = "살릴채무자키")
    sr_revive.to_excel(join(path_base, "revive_"+date_of_data+".xlsx"), index=False)
    print(f"살릴 것이 {len(set_revive)}개 있습니다.")
else : print(f"살릴 것이 없음.")

### 1220 기준 살릴 것 모두 살림
# Out:
# 살릴 것이 304개 있습니다.

# %% [markdown]
# ##### 죽일거(kill = 신out -구out)

# %%
# 위 셀 실행 후에 
# 살릴거(revive) 구하기
set_kill = set_outList_new - set_outList_old

# 살릴 거 있으면 저장해두고 작업하자
if len(set_kill) > 0 :
    sr_revive = pd.Series(list(set_kill), name="관리제외할채무자키")
    sr_revive.to_excel(join(path_base, "kill_"+date_of_data+".xlsx"), index=False)
    print(f"관리제외할 파일이 서버에 {len(set_kill)}개 있습니다.")
else : print(f"관리제외할 파일이 서버에 없습니다.")
# Out:
# 관리제외할 파일이 서버에 439개 있습니다.

# %% [markdown]
# ##### 신규 종결건 처리하기(죽일거) - nas에서 할 수 있게 만들어야겠다.. 시간 너무 걸려

# %%
# 필요 파일 불러오기 ----------------------
# 파일 관리제외할 채무자키 목록(depth3), 매각사 불러올 dict_refer(depth2), 문서구분(depth1)
############################
kill_filename = "kill_20221220.xlsx"
dict_refer_name = "dict_refer_20221220.pkl"
############################
kill = pd.read_excel(join(path_base, kill_filename)).iloc[:,0].to_list() # 리스트
dict_refer = pd.read_pickle(join(path_base, dict_refer_name)) # dict_refer[key][0] : 매각사구분

docu_folder_dict = {"원인서류": "1.원인서류", "양도통지서": "2.양도통지서", "집행권원": "3.집행권원", "강제집행": "4.강제집행", 
        "등본": "5.등초본", "법인등기" : "5.등초본", "초본": "5.등초본", "등초본":"5.등초본", "외국인증명": "5.등초본", "주민등록정보":"5.등초본", 
        "개인회생": "6.개인회생", "신용회복": "7.신용회복", "파산": "8.파산", "재산조사": "9.재산조사", "부채증명서" : "10.부채증명서", 
        "신용조회" : "11.신용조회", "개인정보":"12.개인정보", "기타": "기타"}
depth1 = list(docu_folder_dict.values())

# %%
# dict_kcs 를 위한 import 및 함수
import binascii
def crc32_checksum(filename):
    buf = open(filename,'rb').read()
    buf = (binascii.crc32(buf) & 0xFFFFFFFF)
    return "%08X" % buf

def get_kcs(path_192) :
    crc32 = str(crc32_checksum(path_192))
    size = str(os.path.getsize(path_192))
    f = os.path.split(path_192)[1]
    key = f[:8]
    kcs = key + crc32 + size 
    return kcs

def read_kcs(path_kcs) :
    with open(path_kcs, "rb") as pkl :
        return pickle.load(pkl)

def delete_kcs(filePath, dict_kcs) :
    k = os.path.split(filePath)[1][:8]
    c = str(crc32_checksum(filePath))
    s = str(os.path.getsize(filePath))
    kcs = k + c + s
    if kcs in dict_kcs :
        del dict_kcs[kcs]
        print("kcs를 삭제하였습니다.")
    else :
      print(kcs, "없는 키값")
      
def write_kcs(path_kcs, dict_kcs) :
    with open(path_kcs, "wb") as pkl :
        pickle.dump(dict_kcs, pkl)
    print(len(dict_kcs))

path_kcs = r"\\192.168.0.75\스캔파일\스캔파일log\_project\파일\중복조사\kcs별 파일정보_솔림헬프.pkl"
dict_kcs = read_kcs(path_kcs)
print(len(dict_kcs))
# Out:
# 342825

# %%
# (끝) path에 신규 종결건 파일이 있는 경우만 골라서 관리제외 폴더로 옮기기
path = r"\\192.168.0.75\솔림헬프"
out_dir_base = r"\\192.168.0.75\삭제예정파일\관리제외"
path_log = r'\\192.168.0.75\스캔파일\스캔파일log\_project\파일\채무자조회 구버전'
success_key, success, fail = [], [], []
dir_cnt = 0

print(len(kill),"개의 채무자키에 대한 관리제외 작업을 시작합니다.")
print("작업 전 dict_kcs개수 : ", len(dict_kcs))
for d1 in tqdm(depth1, total=13) : 
    for d3 in kill :
        d3 = str(d3)
        d2 = dict_refer[d3][0]
        src_d = join(path, d1, d2, d3)

        if os.path.exists(src_d) :
            dst_d = join(out_dir_base, d2, d3)
            if not os.path.exists(dst_d) :
                os.makedirs(dst_d)

            for f in os.listdir(src_d) :  # 파일 옮기기
                try :
                    # dict_kcs 삭제하기
                    delete_kcs(join(src_d, f), dict_kcs)

                    # 파일 옮기기
                    success.append(re_name_upload(join(src_d, f), join(dst_d, f)))

                except Exception as e :    
                    fail.append([src_d, f, dst_d, f, e.__class__])
                    continue
            
            try : 
                os.rmdir(src_d) # 빈폴더 삭제하기
                dir_cnt += 1
            except Exception as e : 
                print(e)
            success_key.append([d3, "작업완료"])
            print(d3,"에 대한 작업 완료")
        else : 
            print(d3, "폴더, 파일 없어 작업pass")
            success_key.append([d3, "폴더,파일 없음"])

# dict_kcs 저장
write_kcs(path_kcs, dict_kcs)
            
print("작업 후 dict_kcs 개수 : ", len(dict_kcs))
print(len(success),"개의 파일 이동")
print(len(fail),"개의 파일 이동 실패")
print(len(success_key),"개의 dir작업완료")
print(dir_cnt,"개의 폴더 삭제")
write_log_csv_upload(success, path_log, "신규out success")
write_log_csv_upload(fail, path_log, "신규out fail")
write_log_csv_upload(success_key, path_log, "신규out key단위log")
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# 삭제 전 :  345243
# kcs : 204094100180D9CE1041333   path : /volume1/솔림헬프/1.원인서류/유안타저-01/20409410/20409410_서명옥_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345242
# 삭제 전 :  345242
# kcs : 20435667BE2F0D84685398   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20435667/20435667_조경호_원인서류_(1).pdf
# 삭제하였습니다.
# 삭제 후 :  345241
# 삭제 전 :  345241
# kcs : 20435667BE900EF044433   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20435667/20435667_조경호_원인서류_(2).pdf
# 삭제하였습니다.
# 삭제 후 :  345240
# 삭제 전 :  345240
# kcs : 204402549B4815CD44504   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20440254/20440254_권영수_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345239
# 삭제 전 :  345239
# kcs : 204402546E70574B653451   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20440254/20440254_권영수_원인서류_(2).pdf
# 삭제하였습니다.
# 삭제 후 :  345238
# 삭제 전 :  345238
# kcs : 2042346070129E2A4185076   path : /volume1/솔림헬프/1.원인서류/산은캐-01/20423460/20423460_김은숙 한양종합물류_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345237
# 삭제 전 :  345237
# kcs : 2043548645DDB04944936   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20435486/20435486_양충석_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345236
# 삭제 전 :  345236
# kcs : 20421745258120F4745287   path : /volume1/솔림헬프/1.원인서류/한울가람/20421745/20421745_한운희_원인서류_(1).pdf
# 삭제하였습니다.
# 삭제 후 :  345235
# 삭제 전 :  345235
# kcs : 20440923C124DCB3424175   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20440923/20440923_유선호_원인서류_(1).pdf
# 삭제하였습니다.
# 삭제 후 :  345234
# 삭제 전 :  345234
# kcs : 20440923F7130C2D44385   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20440923/20440923_유선호_원인서류_(2).pdf
# 삭제하였습니다.
# 삭제 후 :  345233
# 삭제 전 :  345233
# kcs : 2046300272F5BB1F666434   path : /volume1/솔림헬프/1.원인서류/우담-01/20463002/20463002_이상훈_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345232
# 삭제 전 :  345232
# kcs : 204238624A59FB4E2349615   path : /volume1/솔림헬프/1.원인서류/흥국화재-01/20423862/20423862_김화자_원인서류_녹취파일_160803.wav
# 삭제하였습니다.
# 삭제 후 :  345231
# 삭제 전 :  345231
# kcs : 20444720B233756644459   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20444720/20444720_김영수_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345230
# 삭제 전 :  345230
# kcs : 204078530DB18B79532634   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20407853/20407853_지종기_원인서류_(1).pdf
# 삭제하였습니다.
# 삭제 후 :  345229
# 삭제 전 :  345229
# kcs : 204078534BD4428744205   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20407853/20407853_지종기_원인서류_(2).pdf
# 삭제하였습니다.
# 삭제 후 :  345228
# 삭제 전 :  345228
# kcs : 20464665217D933E2960543   path : /volume1/솔림헬프/1.원인서류/우담-01/20464665/20464665_한은애_원인서류.tif
# 삭제하였습니다.
# 삭제 후 :  345227
# 삭제 전 :  345227
# kcs : 204258412DA33DE825293   path : /volume1/솔림헬프/1.원인서류/KCR/20425841/20425841_신금순_원인서류.tif
# 삭제하였습니다.
# 삭제 후 :  345226
# 삭제 전 :  345226
# kcs : 204997351A1BAEEB114622   path : /volume1/솔림헬프/1.원인서류/베리타스-01/20499735/20499735_배상준_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345225
# 삭제 전 :  345225
# kcs : 204989257E0CFEB0237983   path : /volume1/솔림헬프/1.원인서류/베리타스-01/20498925/20498925_유연수_원인서류_여타문서포함.pdf
# 삭제하였습니다.
# 삭제 후 :  345224
# 삭제 전 :  345224
# kcs : 20437109355C13B044443   path : /volume1/솔림헬프/1.원인서류/KB카드-01/20437109/20437109_김명찬_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345223
# 삭제 전 :  345223
# kcs : 205001770ADFFAAB1702314   path : /volume1/솔림헬프/1.원인서류/베리타스-01/20500177/20500177_이현서_원인서류.pdf
# 삭제하였습니다.
# 삭제 후 :  345222
# 삭제 전 :  345222
# kcs : 20500177AE133B9F115950   path : /volume1/솔림헬프/1.원인서류/베리타스-01/20500177/20500177_이현서_원인서류_여타문서포함.pdf
# 삭제하였습니다.
# 삭제 후 :  
기타_매각사 여타서류모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342835
# 삭제 전 :  342835
# kcs : 204401487CCF0AB95637443   path : /volume1/솔림헬프/기타/KB카드-01/20440148/20440148_CHEN XIUJUN_기타_2022차전116527_보정명령.pdf
# 삭제하였습니다.
# 삭제 후 :  342834
# 삭제 전 :  342834
# kcs : 20440148EAD139D45510883   path : /volume1/솔림헬프/기타/KB카드-01/20440148/20440148_CHEN XIUJUN_기타_보정명령서.pdf
# 삭제하였습니다.
# 삭제 후 :  342833
# 삭제 전 :  342833
# kcs : 2046065802AC0AAE1305526   path : /volume1/솔림헬프/기타/우담-01/20460658/20460658_김몽규_기타_매각사 여타서류모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342832
# 삭제 전 :  342832
# kcs : 204635239D212BCD489585   path : /volume1/솔림헬프/기타/우담-01/20463523/20463523_박종우_기타_매각사 여타서류모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342831
# 삭제 전 :  342831
# kcs : 205005680A845B4A6658116   path : /volume1/솔림헬프/기타/베델-01/20500568/20500568_김원득_기타_매각사 여타문서모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342830
# 삭제 전 :  342830
# kcs : 20465489F8E6B1A8144435   path : /volume1/솔림헬프/기타/우담-01/20465489/20465489_최섬결_기타_매각사 여타서류모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342829
# 삭제 전 :  342829
# kcs : 20515223C9DB160150115510   path : /volume1/솔림헬프/기타/퀀텀-01/20515223/20515223_박미진_기타_매각사자료모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342828
# 삭제 전 :  342828
# kcs : 204999732B2FDDA21558537   path : /volume1/솔림헬프/기타/베리타스-01/20499973/20499973_한지유_기타_매각사 여타서류모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342827
# 삭제 전 :  342827
# kcs : 20426563BA4537FE5608178   path : /volume1/솔림헬프/기타/KCR/20426563/20426563_이강희_기타_신청서약관 등.pdf
# 삭제하였습니다.
# 삭제 후 :  342826
# 삭제 전 :  342826
# kcs : 204636318C9E265D71712   path : /volume1/솔림헬프/기타/우담-01/20463631/20463631_김은영_기타_매각사 여타서류모음.pdf
# 삭제하였습니다.
# 삭제 후 :  342825
# 18it [42:44, 142.45s/it]
# 2418 개의 파일 이동
# 1 개의 파일 이동 실패
# 1359 개의 폴더 삭제

# %%
# 전체 os.walk 하는 비효율적인 코드
# path = r"\\192.168.0.75\솔림헬프"
# out_dir_base = r"\\192.168.0.75\관리제외"
# path_log = r'\\192.168.0.75\스캔파일\스캔파일log\_project\파일\채무자조회 구버전'
# success = []
# fail = []
# dir_cnt = 0
# for root, __dirs__, files in tqdm(os.walk(path)) :
#     if re.search("#recycle", root) == None : # 휴지통 nono
#         for key in result :
#             try : 
#                 if re.search(key, root) :
#                     depth2 = root.split(os.path.sep)[-2]
#                     depth3 = root.split(os.path.sep)[-3]
#                     out_dir = join(out_dir_base, depth2, depth3)
                    
#                     # if not os.path.exists(out_dir) :
#                     #     os.makedirs(out_dir)
#                     try :
#                         for f in os.listdir(root) :
#                             success.append([join(root, f), join(out_dir, f)])
#                             # success.append(re_name_upload(join(root, f), join(out_dir, f)))
#                     except Exception as e :    
#                         fail.append([root, f, out_dir, f, e.__class__])
#                         continue
            
#                     # os.rmdir(out_dir)
#                     # dir_cnt += 1
#                     break
#             except Exception as e : 
#                 print(e.with_traceback())
#                 continue
                
# print(len(success),"개의 파일 이동")
# print(len(fail),"개의 파일 이동 실패")
# print(dir_cnt,"개의 폴더 삭제")
# write_log_csv_upload(success, path_log, "success")
# write_log_csv_upload(fail, path_log, "fail")
# Out:
# 453 개의 파일 이동
# 0 개의 파일 이동 실패
# 0 개의 폴더 삭제
# log 파일이 비어있습니다. path : \\192.168.0.75\스캔파일\스캔파일log\_project\파일\채무자조회 구버전

# %% [markdown]
# ##### 채무자조회 컬럼 추가

# %%
import pandas as pd
import pickle

# %%
with open(r"D:\0.전산\1.진행중과업\파일서버개편\파일\extraKey\계좌조회새창_20221124_1008.pkl", "rb") as pkl :
    df_left = pickle.load(pkl)
df_left
# Out:
#            채무자키   매각사구분              계좌번호       최초대출일       최초연체일     은행대출원금  \
# 0      20412714  DNP-02  1375-16-01001756  2003-04-30         NaN  400000000
# 1      20412714  DNP-02  5052-16-10081511  2002-06-27         NaN  300000000
# 2      20412714  DNP-02  5052-16-10081863  2002-07-23         NaN  200000000
# 3      20412714  DNP-02  5052-16-10082013  2002-07-30         NaN  100000000
# 4      20455180  DNP-01  8288-09-01017811  2000-10-20         NaN          0
# ...         ...     ...               ...         ...         ...        ...
# 78149  20527985  카카오-01     3650031435424  2018-04-06  2022-04-07   37500000
# 78150  20527986  카카오-01     3650011051361  2017-10-09  2019-10-11    5000000
# 78151  20527987  카카오-01     3650013698082  2018-09-21  2021-06-18   21000000
# 78152  20527988  카카오-01     3650030453818  2019-06-12  2020-12-10    3000000
# 78153  20527989  카카오-01     3650011641045  2017-12-14  2020-11-07   26000000
#
#             최초원금   원채권사  원채권키           채무자명         채무자주민번호      채무상태  \
# 0      400000000   국민은행     0  ㈜원숭이학교 대표 정희원    404-81-13967        폐업
# 1      250000000   국민은행     0  ㈜원숭이학교 대표 정희원    404-81-13967        폐업
# 2      197799852   국민은행     0  ㈜원숭이학교 대표 정희원    404-81-13967        폐업
# 3      100000000   국민은행     0  ㈜원숭이학교 대표 정희원    404-81-13967        폐업
# 4              0   국민은행     0            전윤선  541012-2683023        매각
# ...          ...    ...   ...            ...             ...       ...
# 78149   36765870  카카오뱅크     0            김종연  750529-1390310  신용회복(확정)
# 78150    3251178  카카오뱅크     0            정윤미  841003-2652623  신용회복(확정)
# 78151   21000000  카카오뱅크     0            박정업  720215-1221241  개인회생(확정)
# 78152   22777210  카카오뱅크     0            김태수  890406-1111416  개인회생(확정)
# 78153   26000000  카카오뱅크     0            강성원  770823-1113611  개인회생(확정)
#
#                타채무자키       타계좌키
# 0         0405001212        NaN
# 1         0405001212        NaN
# 2         0405001212        NaN
# 3         0405001212        NaN
# 4         0405001221        NaN
# ...              ...        ...
# 78149  3650031435424   CCRS-467
# 78150  3650011051361  CCRS-1023
# 78151  3650013698082    IRL-846
# 78152  3650030453818    IRL-815
# 78153  3650011641045    IRL-112
#
# [78154 rows x 14 columns]

# %%
# df_right = pd.read_excel(r'c://Users/SL/Desktop/')
# df_right
with open(r"D:\0.전산\1.진행중과업\파일서버개편\파일\extraKey\전화 주소_20221124_1313.pkl", "rb") as pkl :
    df_right = pickle.load(pkl)
df_right
# Out:
#            채무자키         자택전화인         직장전화인           핸드폰인  \
# 0      20495151  063-227-0416           NaN            NaN
# 1      20495152  063-227-0416           NaN            NaN
# 2      20495238  063-227-0416           NaN            NaN
# 3      20417854  063-832-5411  063-834-9912   011-944-6480
# 4      20411449           NaN  063-644-3008  010-4652-6956
# ...         ...           ...           ...            ...
# 70787  20459682           NaN  051-660-3056  010-9512-0243
# 70788  20459636           NaN  051-205-5177  010-8687-5147
# 70789  20447783           NaN  043-530-3200            NaN
# 70790  20459338           NaN           NaN  010-7659-9939
# 70791  20459630           NaN           NaN  010-4671-8941
#
#                         자택주소               자택번지인                   직장주소  \
# 0               전라북도 임실군 신평면         석등슬치로 354-1                    NaN
# 1               전라북도 임실군 신평면         석등슬치로 354-1                    NaN
# 2               전라북도 임실군 신평면         석등슬치로 354-1                    NaN
# 3                 전북 익산시 어양동  510-1 어양아파트 12-411             전북 익산시 어양동
# 4                        NaN                 NaN             전북 임실군 오수면
# ...                      ...                 ...                    ...
# 70787       부산 남구 용소로64번길 60     301호 (대연동,쿨하우스)              부산 남구 용당동
# 70788      부산 강서구 녹산산업중로 409               (송정동)      부산 강서구 녹산산업중로 409
# 70789        서울 용산구 이태원로 223          534호 (한남동)  충북 진천군 이월면 생거진천로 1770
# 70790      서울 용산구 신흥로11나길 17             (용산동2가)                      0
# 70791  경기 안양시 만안구 장내로89번길 45          B03호 (안양동)                      0
#
#                            직장번지인                       초본주소  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                        657-4번지                        NaN
# 4                    금암리 761-3번지      전북 임실군 오수면 금암1길 39-16
# ...                          ...                        ...
# 70787  산100번지 부경대학교용당캠퍼스 한미르관 4층                        NaN
# 70788                      (송정동)                        NaN
# 70789                      (중산리)            전북 익산시 고봉로 146,
# 70790                          0                        NaN
# 70791                          0  경기 안양시 만안구 장내로100번길 20-2,
#
#                      초본번지인
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                    (금암리)
# ...                    ...
# 70787                  NaN
# 70788                  NaN
# 70789  7동306호 (마동,주공1차아파트)
# 70790                  NaN
# 70791          3층 1호 (안양동)
#
# [70792 rows x 10 columns]

# %%
# 삭제할 col 있는 경우
# df_right.drop(['은행대출원금', '최초원금'], axis=1, inplace=True)
# df_right
# Out:
#            채무자키       현재원금
# 0      20455180          0
# 1      20455180          0
# 2      20455181          0
# 3      20411129          0
# 4      20412715          0
# ...         ...        ...
# 78149  20419638  999109587
# 78150  20429686          0
# 78151  20430085          0
# 78152  20494438   89420225
# 78153  20494469  149952000
#
# [78154 rows x 2 columns]

# %%
# 결과가 이상하면 기준셀이 key가 아닌지 확인하라.
df_result = pd.merge(df_left, df_right, how='left')
df_result
# Out:
#            채무자키   매각사구분              계좌번호       최초대출일       최초연체일     은행대출원금  \
# 0      20412714  DNP-02  1375-16-01001756  2003-04-30         NaN  400000000
# 1      20412714  DNP-02  5052-16-10081511  2002-06-27         NaN  300000000
# 2      20412714  DNP-02  5052-16-10081863  2002-07-23         NaN  200000000
# 3      20412714  DNP-02  5052-16-10082013  2002-07-30         NaN  100000000
# 4      20455180  DNP-01  8288-09-01017811  2000-10-20         NaN          0
# ...         ...     ...               ...         ...         ...        ...
# 78149  20527985  카카오-01     3650031435424  2018-04-06  2022-04-07   37500000
# 78150  20527986  카카오-01     3650011051361  2017-10-09  2019-10-11    5000000
# 78151  20527987  카카오-01     3650013698082  2018-09-21  2021-06-18   21000000
# 78152  20527988  카카오-01     3650030453818  2019-06-12  2020-12-10    3000000
# 78153  20527989  카카오-01     3650011641045  2017-12-14  2020-11-07   26000000
#
#             최초원금   원채권사  원채권키           채무자명  ...       타계좌키 자택전화인 직장전화인  \
# 0      400000000   국민은행     0  ㈜원숭이학교 대표 정희원  ...        NaN   NaN   NaN
# 1      250000000   국민은행     0  ㈜원숭이학교 대표 정희원  ...        NaN   NaN   NaN
# 2      197799852   국민은행     0  ㈜원숭이학교 대표 정희원  ...        NaN   NaN   NaN
# 3      100000000   국민은행     0  ㈜원숭이학교 대표 정희원  ...        NaN   NaN   NaN
# 4              0   국민은행     0            전윤선  ...        NaN   NaN   NaN
# ...          ...    ...   ...            ...  ...        ...   ...   ...
# 78149   36765870  카카오뱅크     0            김종연  ...   CCRS-467   NaN   NaN
# 78150    3251178  카카오뱅크     0            정윤미  ...  CCRS-1023   NaN   NaN
# 78151   21000000  카카오뱅크     0            박정업  ...    IRL-846   NaN   NaN
# 78152   22777210  카카오뱅크     0            김태수  ...    IRL-815   NaN   NaN
# 78153   26000000  카카오뱅크     0            강성원  ...    IRL-112   NaN   NaN
#
#                 핸드폰인             자택주소                           자택번지인 직장주소  \
# 0                NaN              NaN                             NaN  NaN
# 1                NaN              NaN                             NaN  NaN
# 2                NaN              NaN                             NaN  NaN
# 3                NaN              NaN                             NaN  NaN
# 4                NaN       경북 경산시 삼북동                          266-37  NaN
# ...              ...              ...                             ...  ...
# 78149  010-9138-4420    서울 양천구 목동중앙본로           10 (극동늘푸른아파트) 101-604  NaN
# 78150  010-4748-0609   서울특별시 동대문구 장한로         111-1, 903호 (장안동, sm타워)  NaN
# 78151  010-6235-2501     충청남도 아산시 음봉면      음봉로 847, 101-415 (삼일원앙아파트)  NaN
# 78152  010-5125-9927   부산 사상구 광장로86번길                  32 (E클레스) 101호  NaN
# 78153  010-2523-7043  부산광역시 해운대구 센텀1로  9, S동 1206호 (우동, 롯데갤러리움센텀오피스텔)  NaN
#
#       직장번지인                     초본주소    초본번지인
# 0       NaN     전북 부안군 상서면 부안로 1783,  (원숭이학교)
# 1       NaN     전북 부안군 상서면 부안로 1783,  (원숭이학교)
# 2       NaN     전북 부안군 상서면 부안로 1783,  (원숭이학교)
# 3       NaN     전북 부안군 상서면 부안로 1783,  (원숭이학교)
# 4       NaN  경북 경주시 건천읍 부산성길 271-28,    (만교사)
# ...     ...                      ...      ...
# 78149   NaN                      NaN      NaN
# 78150   NaN                      NaN      NaN
# 78151   NaN                      NaN      NaN
# 78152   NaN                      NaN      NaN
# 78153   NaN                      NaN      NaN
#
# [78154 rows x 23 columns]

# %%
df_result.to_pickle(r"D:\0.전산\1.진행중과업\파일서버개편\파일\extraKey\계좌_주소_통합본.pkl")
